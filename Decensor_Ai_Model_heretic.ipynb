# %% [markdown]
# <a href="https://colab.research.google.com/github/boss-defender/Abliteration/blob/main/Decensor_Ai_Model_heretic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title 🚀 1. Decensor Model (All-in-One Smart Engine & Auto Resume) ⚡
# @markdown Enter any Hugging Face model! Checks GPU, auto-installs packages, mounts Drive, and resumes progress seamlessly.

MODEL_NAME = "Qwen/Qwen3-4B-Thinking-2507"  # @param {type:"string"}
QUANTIZATION = "BNB_4BIT"  # @param ["BNB_4BIT", "NONE"] {allow-input: true}
HUGGINGFACE_TOKEN = ""  # @param {type:"string"}

import os
import shutil
import torch

# -------------------------------------------------------------------
# 🔍 1. GPU Diagnostics & VRAM Sanity Check
# -------------------------------------------------------------------
print("🩺 Running Pre-Flight System Diagnostics...")

if not torch.cuda.is_available():
  print(
      "\n❌ CRITICAL ERROR: No GPU detected!"
      "\n👉 Please go to top menu: Runtime -> Change runtime type -> Select T4 GPU"
      " (or A100)."
  )
  raise SystemExit("🚨 Process paused: GPU hardware is required to run Heretic.")
else:
  gpu_name = torch.cuda.get_device_name(0)
  vram_gb = torch.cuda.get_device_properties(0).total_memory / (1024**3)
  print(
      f"✅ GPU Online: {gpu_name} ({vram_gb:.2f} GB VRAM available) - Ready to"
      " melt weights! 🔥\n"
  )

# -------------------------------------------------------------------
# 📁 2. Mount Google Drive & Isolate Model Checkpoints
# -------------------------------------------------------------------
print("📁 Connecting Google Drive...")
from google.colab import drive

drive.mount("/content/drive")

# Generate a unique checkpoint folder based on the model name
clean_model_name = MODEL_NAME.replace("/", "_")
CHECKPOINT_DIR = (
    f"/content/drive/MyDrive/heretic_checkpoints/{clean_model_name}"
)
os.makedirs(CHECKPOINT_DIR, exist_ok=True)
print("✅ Drive connected! Checkpoint folder ready.\n")

# -------------------------------------------------------------------
# ⚙️ 3. Auto-Install Heretic Engine & others (if missing from session)
# -------------------------------------------------------------------

print("🛠️ Heretic engine & torchao installing now...")
# !pip install -U torchao
# !pip install -q -U heretic-llm bitsandbytes accelerate huggingface_hub
print("🎉 Heretic & CUDA packages & torchao installed successfully!\n")



# -------------------------------------------------------------------
# 🔑 4. Hugging Face Authentication
# -------------------------------------------------------------------
clean_hf_token = HUGGINGFACE_TOKEN.strip()
if clean_hf_token:
    os.environ["HF_TOKEN"] = clean_hf_token
    # !huggingface-cli login --token "$clean_hf_token"

# -------------------------------------------------------------------
# 🔥 5. Launch Heretic Engine!
# -------------------------------------------------------------------
print(f"\n🚀 Igniting Heretic on model: {MODEL_NAME}")
print(f"💾 Isolated Checkpoint Folder: {CHECKPOINT_DIR}\n")

# !heretic --model "{MODEL_NAME}" --quantization {QUANTIZATION} --study-checkpoint-dir "{CHECKPOINT_DIR}"

print("\n✅ Decensoring process complete! You can move to the next cell to zip and download.")
# Out:
# 🩺 Running Pre-Flight System Diagnostics...
# ✅ GPU Online: Tesla T4 (14.56 GB VRAM available) - Ready to melt weights! 🔥
#
# 📁 Connecting Google Drive...
# Mounted at /content/drive
# ✅ Drive connected! Checkpoint folder ready.
#
# 🛠️ Heretic engine missing from current session! Installing now...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 17.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.1/64.1 kB 6.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.1/43.1 MB 27.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 795.8/795.8 kB 28.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.0/529.0 kB 23.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 63.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 65.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 425.6/425.6 kB 17.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 kB 9.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.5/310.5 kB 15.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.9/265.9 kB 12.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.4/65.4 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 MB 11.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 9.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 9.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 66.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.7/111.7 kB 11.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.6/129.6 kB 9.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 65.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.3/55.3 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 876.1/876.1 kB 51.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 25.7 MB/s eta 0:00:00
#   Building wheel for langdetect (setup.py) ... done
#   Building wheel for rouge-score (setup.py) ... done
#   Building wheel for sqlitedict (setup.py) ... done
#   Building wheel for word2number (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.42.0 requires rich<14,>=12.4.4, but you have rich 14.3.4 which is incompatible.
# numba 0.61.2 requires numpy<2.3,>=1.24, but you have numpy 2.5.2 which is incompatible.
# 🎉 Heretic & CUDA packages installed successfully!
#
#
# 🚀 Igniting Heretic on model: Qwen/Qwen3-4B-Thinking-2507
# 💾 Isolated Checkpoint Folder: /content/drive/MyDrive/heretic_checkpoints/Qwen_Qwen3-4B-Thinking-2507
#
# █░█░█▀▀░█▀▄░█▀▀░▀█▀░█░█▀▀  v1.4.0
# █▀█░█▀▀░█▀▄░█▀▀░░█░░█░█░░  https://heretic-project.org
# ▀░▀░▀▀▀░▀░▀░▀▀▀░░▀░░▀░▀▀▀  https://github.com/p-e-w/heretic
#
# Detected 1 CUDA device(s) (14.56 GB total VRAM)
# CUDA Version: 12.8
# Driver Version: 580.82.07
# * CUDA 0: Tesla T4 (14.56 GB)
#
# You have already processed this model, but the run was interrupted. You can
# continue the previous run from where it stopped. This will override any
# specified settings. Alternatively, you can ignore the previous run and start
# from scratch. This will delete the checkpoint file and all results from the
# previous run.
#
#
# How would you like to proceed?
# [1] Continue the previous run
# [2] Ignore the previous run and start from scratch
# [3] Exit program
# Enter number: 1
#
# Loading model Qwen/Qwen3-4B-Thinking-2507...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 100% 727/727 [00:00<00:00, 3.18MB/s]
# tokenizer_config.json: 100% 10.8k/10.8k [00:00<00:00, 28.5MB/s]
# vocab.json: 100% 2.78M/2.78M [00:00<00:00, 47.3MB/s]
# merges.txt: 100% 1.67M/1.67M [00:00<00:00, 74.8MB/s]
#
# tokenizer.json: downloading bytes:   0% 0.00/11.4M [00:00<?, ?B/s]
# tokenizer.json: downloading bytes: 100% 3.40M/3.40M [00:00<00:00, 6.88MB/s,  337kB/s  ]
# tokenizer.json: reconstructing file: 100% 11.4M/11.4M [00:00<00:00, 23.1MB/s, 1.13MB/s  ]
# * Trying dtype auto...
# model.safetensors.index.json: 100% 32.8k/32.8k [00:00<00:00, 64.8MB/s]
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 3 files:   0% 0/3 [00:00<?, ?it/s]
# Reconstructing (incomplete total...):   0% 0.00/3.99G [00:00<?, ?B/s]
# Reconstructing (incomplete total...):   0% 0.00/8.04G [00:00<?, ?B/s]
# Downloading bytes:   5% 412M/8.04G [00:01<00:22, 336MB/s,  333MB/s  ]
# Downloading bytes:  13% 1.06G/8.04G [00:03<00:24, 289MB/s,  336MB/s  ]
# Reconstructing (incomplete total...):   2% 167M/8.04G [00:03<02:54, 45.3MB/s, 38.4MB/s  ]
#
# Downloading bytes:  17% 1.36G/8.04G [00:04<00:21, 309MB/s,  301MB/s  ]
# Downloading bytes:  30% 2.41G/8.04G [00:10<01:05, 86.7MB/s, 81.4MB/s  ]
# Downloading bytes:  55% 4.41G/8.04G [00:18<00:12, 282MB/s,  299MB/s  ]
# Downloading bytes:  56% 4.48G/8.04G [00:19<00:18, 192MB/s,  189MB/s  ]
# Downloading bytes:  87% 6.99G/8.04G [00:31<00:03, 288MB/s,  298MB/s  ]
# Reconstructing (incomplete total...):  25% 1.98G/8.04G [00:32<02:01, 50.1MB/s,  113MB/s  ]
# Downloading bytes:  87% 7.00G/8.04G [00:47<00:03, 288MB/s,  288MB/s  ]
# Reconstructing (incomplete total...):  42% 3.39G/8.04G [01:38<02:57, 26.2MB/s, 50.1MB/s  ]
# Reconstructing (incomplete total...):  42% 3.39G/8.04G [01:57<02:57, 26.2MB/s, 26.2MB/s  ]
# Reconstructing (incomplete total...):  61% 4.93G/8.04G [02:29<01:51, 28.1MB/s, 26.2MB/s  ]
# Reconstructing (incomplete total...):  73% 5.90G/8.04G [02:40<00:59, 36.0MB/s, 28.1MB/s  ]
#
# Fetching 3 files:  67% 2/3 [02:42<01:34, 94.69s/it]
# Reconstructing (incomplete total...):  73% 5.90G/8.04G [02:57<00:59, 36.0MB/s, 36.0MB/s  ]
# Reconstructing (incomplete total...):  92% 7.44G/8.04G [03:02<00:13, 44.9MB/s, 36.0MB/s  ]
# Reconstructing (incomplete total...): 100% 8.04G/8.04G [03:13<00:00, 46.8MB/s, 44.9MB/s  ]
#
# Fetching 3 files: 100% 3/3 [03:13<00:00, 64.38s/it]
# Download complete: 100% 7.00G/7.00G [03:13<00:00, 288MB/s,  288MB/s  ]
# Download complete: 100% 7.00G/7.00G [03:15<00:00, 35.9MB/s,  288MB/s  ]
# Reconstruction complete: 100% 8.04G/8.04G [03:15<00:00, 41.2MB/s, 46.8MB/s  ]
# Loading weights: 100% 398/398 [00:23<00:00, 16.88it/s]
# generation_config.json: 100% 239/239 [00:00<00:00, 912kB/s]
# * Quantized to 4-bit precision
# * LoRA adapters initialized (target types: down_proj, o_proj)
# * Transformer model with 36 layers
# * Abliterable components:
#   * attn.o_proj: 36 modules total
#   * mlp.down_proj: 36 modules total
#
# Resident system RAM: 1.69 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 2.59 GB
#
# Loading good prompts from mlabonne/harmless_alpaca...
# README.md: 100% 388/388 [00:00<00:00, 1.76MB/s]
#
# data/train-00000-of-00001.parquet: downloading bytes:  89% 861k/972k [00:00<00:00, 2.63MB/s]
# data/train-00000-of-00001.parquet: downloading bytes: 100% 963k/963k [00:00<00:00, 2.92MB/s, 95.7kB/s  ]
# data/train-00000-of-00001.parquet: reconstructing file: 100% 972k/972k [00:00<00:00, 2.94MB/s, 96.6kB/s  ]
#
# data/test-00000-of-00001.parquet: downloading bytes:   0% 0.00/243k [00:00<?, ?B/s]
# data/test-00000-of-00001.parquet: downloading bytes: 100% 243k/243k [00:00<00:00, 807kB/s, 24.1kB/s  ]
# data/test-00000-of-00001.parquet: reconstructing file: 100% 243k/243k [00:00<00:00, 808kB/s, 24.2kB/s  ]
# Generating train split: 100% 25058/25058 [00:00<00:00, 174268.60 examples/s]
# Generating test split: 100% 6265/6265 [00:00<00:00, 838646.62 examples/s]
# * 400 prompts loaded
#
# Loading bad prompts from mlabonne/harmful_behaviors...
# README.md: 100% 381/381 [00:00<00:00, 2.15MB/s]
#
# data/train-00000-of-00001.parquet: downloading bytes:   0% 0.00/15.0k [00:00<?, ?B/s]
# data/train-00000-of-00001.parquet: downloading bytes: 100% 14.7k/14.7k [00:00<00:00, 44.4kB/s, 1.46kB/s  ]
# data/train-00000-of-00001.parquet: reconstructing file: 100% 15.0k/15.0k [00:00<00:00, 45.2kB/s, 1.49kB/s  ]
#
# data/test-00000-of-00001.parquet: downloading bytes:   0% 0.00/5.46k [00:00<?, ?B/s]
# data/test-00000-of-00001.parquet: downloading bytes: 100% 5.03k/5.03k [00:00<00:00, 23.4kB/s,   ???B/s  ]
# data/test-00000-of-00001.parquet: reconstructing file: 100% 5.46k/5.46k [00:00<00:00, 25.4kB/s,   ???B/s  ]
# Generating train split: 100% 416/416 [00:00<00:00, 150598.18 examples/s]
# Generating test split: 100% 104/104 [00:00<00:00, 55645.82 examples/s]
# * 400 prompts loaded
#
# Loading good evaluation prompts from mlabonne/harmless_alpaca...
# * 100 prompts loaded
# * Obtaining first-token probability distributions...
#
# Loading bad evaluation prompts from mlabonne/harmful_behaviors...
# * 100 prompts loaded
# * Counting model refusals...
# * Initial refusals: 99/100
#
# Calculating per-layer refusal directions...
# * Obtaining residual mean for good prompts...
# * Obtaining residual mean for bad prompts...
#
# Resuming existing study.
#
# Running trial 149 of 200...
# * Parameters:
#   * direction_index = 18.38
#   * attn.o_proj.max_weight = 1.32
#   * attn.o_proj.max_weight_position = 22.41
#   * attn.o_proj.min_weight = 0.27
#   * attn.o_proj.min_weight_distance = 13.61
#   * mlp.down_proj.max_weight = 1.14
#   * mlp.down_proj.max_weight_position = 26.83
#   * mlp.down_proj.min_weight = 0.03
#   * mlp.down_proj.min_weight_distance = 17.51
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0012
#   * Counting model refusals...
#   * Refusals: 11/100
#
# Elapsed time: 1m 54s
# Estimated remaining time: 1h 37m
# Resident system RAM: 1.91 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 150 of 200...
# * Parameters:
#   * direction_index = 18.56
#   * attn.o_proj.max_weight = 1.26
#   * attn.o_proj.max_weight_position = 21.06
#   * attn.o_proj.min_weight = 0.07
#   * attn.o_proj.min_weight_distance = 16.62
#   * mlp.down_proj.max_weight = 1.13
#   * mlp.down_proj.max_weight_position = 26.95
#   * mlp.down_proj.min_weight = 0.03
#   * mlp.down_proj.min_weight_distance = 17.42
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0018
#   * Counting model refusals...
#   * Refusals: 11/100
#
# Elapsed time: 3m 50s
# Estimated remaining time: 1h 35m
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 151 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 1.16
#   * attn.o_proj.max_weight_position = 26.83
#   * attn.o_proj.min_weight = 0.90
#   * attn.o_proj.min_weight_distance = 18.47
#   * mlp.down_proj.max_weight = 1.24
#   * mlp.down_proj.max_weight_position = 23.85
#   * mlp.down_proj.min_weight = 0.42
#   * mlp.down_proj.min_weight_distance = 19.98
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0425
#   * Counting model refusals...
#   * Refusals: 14/100
#
# Elapsed time: 5m 47s
# Estimated remaining time: 1h 34m
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 152 of 200...
# * Parameters:
#   * direction_index = 16.71
#   * attn.o_proj.max_weight = 1.17
#   * attn.o_proj.max_weight_position = 28.50
#   * attn.o_proj.min_weight = 1.11
#   * attn.o_proj.min_weight_distance = 20.67
#   * mlp.down_proj.max_weight = 1.16
#   * mlp.down_proj.max_weight_position = 22.49
#   * mlp.down_proj.min_weight = 0.26
#   * mlp.down_proj.min_weight_distance = 15.37
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0022
#   * Counting model refusals...
#   * Refusals: 14/100
#
# Elapsed time: 7m 44s
# Estimated remaining time: 1h 32m
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 153 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 1.07
#   * attn.o_proj.max_weight_position = 28.29
#   * attn.o_proj.min_weight = 1.01
#   * attn.o_proj.min_weight_distance = 20.45
#   * mlp.down_proj.max_weight = 1.32
#   * mlp.down_proj.max_weight_position = 22.76
#   * mlp.down_proj.min_weight = 0.34
#   * mlp.down_proj.min_weight_distance = 16.58
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0433
#   * Counting model refusals...
#   * Refusals: 14/100
#
# Elapsed time: 9m 40s
# Estimated remaining time: 1h 30m
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 154 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 1.34
#   * attn.o_proj.max_weight_position = 22.80
#   * attn.o_proj.min_weight = 0.58
#   * attn.o_proj.min_weight_distance = 18.88
#   * mlp.down_proj.max_weight = 0.98
#   * mlp.down_proj.max_weight_position = 22.99
#   * mlp.down_proj.min_weight = 0.02
#   * mlp.down_proj.min_weight_distance = 19.40
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0278
#   * Counting model refusals...
#   * Refusals: 14/100
#
# Elapsed time: 11m 37s
# Estimated remaining time: 1h 29m
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 155 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 1.15
#   * attn.o_proj.max_weight_position = 25.74
#   * attn.o_proj.min_weight = 0.93
#   * attn.o_proj.min_weight_distance = 16.68
#   * mlp.down_proj.max_weight = 1.10
#   * mlp.down_proj.max_weight_position = 23.56
#   * mlp.down_proj.min_weight = 0.07
#   * mlp.down_proj.min_weight_distance = 13.58
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0361
#   * Counting model refusals...
#   * Refusals: 20/100
#
# Elapsed time: 13m 35s
# Estimated remaining time: 1h 27m
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 156 of 200...
# * Parameters:
#   * direction_index = 16.96
#   * attn.o_proj.max_weight = 1.45
#   * attn.o_proj.max_weight_position = 27.55
#   * attn.o_proj.min_weight = 1.19
#   * attn.o_proj.min_weight_distance = 18.60
#   * mlp.down_proj.max_weight = 1.11
#   * mlp.down_proj.max_weight_position = 25.67
#   * mlp.down_proj.min_weight = 0.44
#   * mlp.down_proj.min_weight_distance = 18.25
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0023
#   * Counting model refusals...
#   * Refusals: 9/100
#
# Elapsed time: 15m 32s
# Estimated remaining time: 1h 25m
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 157 of 200...
# * Parameters:
#   * direction_index = 17.15
#   * attn.o_proj.max_weight = 1.40
#   * attn.o_proj.max_weight_position = 25.37
#   * attn.o_proj.min_weight = 1.25
#   * attn.o_proj.min_weight_distance = 15.38
#   * mlp.down_proj.max_weight = 1.04
#   * mlp.down_proj.max_weight_position = 25.82
#   * mlp.down_proj.min_weight = 0.52
#   * mlp.down_proj.min_weight_distance = 17.44
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0018
#   * Counting model refusals...
#   * Refusals: 7/100
#
# Elapsed time: 17m 29s
# Estimated remaining time: 1h 23m
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 158 of 200...
# * Parameters:
#   * direction_index = 14.22
#   * attn.o_proj.max_weight = 1.34
#   * attn.o_proj.max_weight_position = 22.89
#   * attn.o_proj.min_weight = 1.25
#   * attn.o_proj.min_weight_distance = 15.53
#   * mlp.down_proj.max_weight = 1.06
#   * mlp.down_proj.max_weight_position = 25.49
#   * mlp.down_proj.min_weight = 0.63
#   * mlp.down_proj.min_weight_distance = 17.10
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0036
#   * Counting model refusals...
#   * Refusals: 67/100
#
# Elapsed time: 19m 26s
# Estimated remaining time: 1h 21m
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 159 of 200...
# * Parameters:
#   * direction_index = 20.03
#   * attn.o_proj.max_weight = 1.40
#   * attn.o_proj.max_weight_position = 28.14
#   * attn.o_proj.min_weight = 1.04
#   * attn.o_proj.min_weight_distance = 8.82
#   * mlp.down_proj.max_weight = 1.12
#   * mlp.down_proj.max_weight_position = 28.38
#   * mlp.down_proj.min_weight = 0.50
#   * mlp.down_proj.min_weight_distance = 16.50
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0015
#   * Counting model refusals...
#   * Refusals: 36/100
#
# Elapsed time: 21m 23s
# Estimated remaining time: 1h 19m
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 160 of 200...
# * Parameters:
#   * direction_index = 17.75
#   * attn.o_proj.max_weight = 1.39
#   * attn.o_proj.max_weight_position = 29.44
#   * attn.o_proj.min_weight = 1.22
#   * attn.o_proj.min_weight_distance = 17.62
#   * mlp.down_proj.max_weight = 1.01
#   * mlp.down_proj.max_weight_position = 24.51
#   * mlp.down_proj.min_weight = 0.52
#   * mlp.down_proj.min_weight_distance = 20.01
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0020
#   * Counting model refusals...
#   * Refusals: 5/100
#
# Elapsed time: 23m 20s
# Estimated remaining time: 1h 17m
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 161 of 200...
# * Parameters:
#   * direction_index = 18.18
#   * attn.o_proj.max_weight = 1.46
#   * attn.o_proj.max_weight_position = 29.34
#   * attn.o_proj.min_weight = 1.23
#   * attn.o_proj.min_weight_distance = 20.63
#   * mlp.down_proj.max_weight = 0.96
#   * mlp.down_proj.max_weight_position = 24.15
#   * mlp.down_proj.min_weight = 0.59
#   * mlp.down_proj.min_weight_distance = 18.35
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0032
#   * Counting model refusals...
#   * Refusals: 4/100
#
# Elapsed time: 25m 17s
# Estimated remaining time: 1h 15m
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 162 of 200...
# * Parameters:
#   * direction_index = 18.19
#   * attn.o_proj.max_weight = 1.33
#   * attn.o_proj.max_weight_position = 31.31
#   * attn.o_proj.min_weight = 1.19
#   * attn.o_proj.min_weight_distance = 20.42
#   * mlp.down_proj.max_weight = 0.95
#   * mlp.down_proj.max_weight_position = 21.45
#   * mlp.down_proj.min_weight = 0.64
#   * mlp.down_proj.min_weight_distance = 17.61
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0027
#   * Counting model refusals...
#   * Refusals: 4/100
#
# Elapsed time: 27m 13s
# Estimated remaining time: 1h 13m
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 163 of 200...
# * Parameters:
#   * direction_index = 15.81
#   * attn.o_proj.max_weight = 1.47
#   * attn.o_proj.max_weight_position = 26.75
#   * attn.o_proj.min_weight = 0.09
#   * attn.o_proj.min_weight_distance = 1.34
#   * mlp.down_proj.max_weight = 1.45
#   * mlp.down_proj.max_weight_position = 22.57
#   * mlp.down_proj.min_weight = 1.03
#   * mlp.down_proj.min_weight_distance = 16.88
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0214
#   * Counting model refusals...
#   * Refusals: 70/100
#
# Elapsed time: 29m 9s
# Estimated remaining time: 1h 11m
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 164 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 0.84
#   * attn.o_proj.max_weight_position = 31.24
#   * attn.o_proj.min_weight = 0.06
#   * attn.o_proj.min_weight_distance = 19.76
#   * mlp.down_proj.max_weight = 1.24
#   * mlp.down_proj.max_weight_position = 28.04
#   * mlp.down_proj.min_weight = 0.77
#   * mlp.down_proj.min_weight_distance = 7.71
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0232
#   * Counting model refusals...
#   * Refusals: 61/100
#
# Elapsed time: 31m 5s
# Estimated remaining time: 1h 9m
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 165 of 200...
# * Parameters:
#   * direction_index = 15.62
#   * attn.o_proj.max_weight = 1.06
#   * attn.o_proj.max_weight_position = 30.97
#   * attn.o_proj.min_weight = 0.02
#   * attn.o_proj.min_weight_distance = 5.93
#   * mlp.down_proj.max_weight = 1.33
#   * mlp.down_proj.max_weight_position = 23.57
#   * mlp.down_proj.min_weight = 0.11
#   * mlp.down_proj.min_weight_distance = 4.42
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0002
#   * Counting model refusals...
#   * Refusals: 98/100
#
# Elapsed time: 33m 1s
# Estimated remaining time: 1h 7m
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 166 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 0.88
#   * attn.o_proj.max_weight_position = 21.29
#   * attn.o_proj.min_weight = 0.57
#   * attn.o_proj.min_weight_distance = 1.89
#   * mlp.down_proj.max_weight = 1.43
#   * mlp.down_proj.max_weight_position = 34.71
#   * mlp.down_proj.min_weight = 0.14
#   * mlp.down_proj.min_weight_distance = 2.99
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0023
#   * Counting model refusals...
#   * Refusals: 82/100
#
# Elapsed time: 34m 56s
# Estimated remaining time: 1h 5m
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 167 of 200...
# * Parameters:
#   * direction_index = 29.77
#   * attn.o_proj.max_weight = 0.85
#   * attn.o_proj.max_weight_position = 25.00
#   * attn.o_proj.min_weight = 0.24
#   * attn.o_proj.min_weight_distance = 7.93
#   * mlp.down_proj.max_weight = 1.30
#   * mlp.down_proj.max_weight_position = 30.43
#   * mlp.down_proj.min_weight = 0.40
#   * mlp.down_proj.min_weight_distance = 1.80
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0014
#   * Counting model refusals...
#   * Refusals: 85/100
#
# Elapsed time: 36m 52s
# Estimated remaining time: 1h 4m
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 168 of 200...
# * Parameters:
#   * direction_index = 27.18
#   * attn.o_proj.max_weight = 1.03
#   * attn.o_proj.max_weight_position = 34.95
#   * attn.o_proj.min_weight = 0.16
#   * attn.o_proj.min_weight_distance = 13.43
#   * mlp.down_proj.max_weight = 0.81
#   * mlp.down_proj.max_weight_position = 34.53
#   * mlp.down_proj.min_weight = 0.25
#   * mlp.down_proj.min_weight_distance = 1.03
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0006
#   * Counting model refusals...
#   * Refusals: 94/100
#
# Elapsed time: 38m 47s
# Estimated remaining time: 1h 2m
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 169 of 200...
# * Parameters:
#   * direction_index = 30.68
#   * attn.o_proj.max_weight = 1.05
#   * attn.o_proj.max_weight_position = 22.70
#   * attn.o_proj.min_weight = 0.39
#   * attn.o_proj.min_weight_distance = 5.45
#   * mlp.down_proj.max_weight = 0.86
#   * mlp.down_proj.max_weight_position = 22.11
#   * mlp.down_proj.min_weight = 0.02
#   * mlp.down_proj.min_weight_distance = 4.46
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0024
#   * Counting model refusals...
#   * Refusals: 82/100
#
# Elapsed time: 40m 42s
# Estimated remaining time: 1h 0m
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 170 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 0.99
#   * attn.o_proj.max_weight_position = 23.28
#   * attn.o_proj.min_weight = 0.03
#   * attn.o_proj.min_weight_distance = 1.75
#   * mlp.down_proj.max_weight = 0.84
#   * mlp.down_proj.max_weight_position = 21.32
#   * mlp.down_proj.min_weight = 0.79
#   * mlp.down_proj.min_weight_distance = 20.53
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0409
#   * Counting model refusals...
#   * Refusals: 59/100
#
# Elapsed time: 42m 38s
# Estimated remaining time: 58m 8s
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 171 of 200...
# * Parameters:
#   * direction_index = 29.62
#   * attn.o_proj.max_weight = 1.01
#   * attn.o_proj.max_weight_position = 25.58
#   * attn.o_proj.min_weight = 0.05
#   * attn.o_proj.min_weight_distance = 20.97
#   * mlp.down_proj.max_weight = 1.48
#   * mlp.down_proj.max_weight_position = 25.48
#   * mlp.down_proj.min_weight = 0.86
#   * mlp.down_proj.min_weight_distance = 18.64
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0131
#   * Counting model refusals...
#   * Refusals: 65/100
#
# Elapsed time: 44m 35s
# Estimated remaining time: 56m 12s
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 172 of 200...
# * Parameters:
#   * direction_index = 22.12
#   * attn.o_proj.max_weight = 1.49
#   * attn.o_proj.max_weight_position = 31.36
#   * attn.o_proj.min_weight = 0.23
#   * attn.o_proj.min_weight_distance = 20.45
#   * mlp.down_proj.max_weight = 1.33
#   * mlp.down_proj.max_weight_position = 23.98
#   * mlp.down_proj.min_weight = 1.14
#   * mlp.down_proj.min_weight_distance = 15.44
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0140
#   * Counting model refusals...
#   * Refusals: 18/100
#
# Elapsed time: 46m 31s
# Estimated remaining time: 54m 16s
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 173 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 0.81
#   * attn.o_proj.max_weight_position = 21.16
#   * attn.o_proj.min_weight = 0.31
#   * attn.o_proj.min_weight_distance = 20.91
#   * mlp.down_proj.max_weight = 1.34
#   * mlp.down_proj.max_weight_position = 26.29
#   * mlp.down_proj.min_weight = 0.24
#   * mlp.down_proj.min_weight_distance = 2.26
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0061
#   * Counting model refusals...
#   * Refusals: 55/100
#
# Elapsed time: 48m 27s
# Estimated remaining time: 52m 20s
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 174 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 0.93
#   * attn.o_proj.max_weight_position = 34.46
#   * attn.o_proj.min_weight = 0.22
#   * attn.o_proj.min_weight_distance = 1.18
#   * mlp.down_proj.max_weight = 0.90
#   * mlp.down_proj.max_weight_position = 23.38
#   * mlp.down_proj.min_weight = 0.18
#   * mlp.down_proj.min_weight_distance = 16.25
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0293
#   * Counting model refusals...
#   * Refusals: 79/100
#
# Elapsed time: 50m 24s
# Estimated remaining time: 50m 24s
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 175 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 1.00
#   * attn.o_proj.max_weight_position = 34.62
#   * attn.o_proj.min_weight = 0.71
#   * attn.o_proj.min_weight_distance = 1.81
#   * mlp.down_proj.max_weight = 0.80
#   * mlp.down_proj.max_weight_position = 24.49
#   * mlp.down_proj.min_weight = 0.04
#   * mlp.down_proj.min_weight_distance = 3.10
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0035
#   * Counting model refusals...
#   * Refusals: 89/100
#
# Elapsed time: 52m 20s
# Estimated remaining time: 48m 27s
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 176 of 200...
# * Parameters:
#   * direction_index = 28.55
#   * attn.o_proj.max_weight = 0.94
#   * attn.o_proj.max_weight_position = 26.26
#   * attn.o_proj.min_weight = 0.48
#   * attn.o_proj.min_weight_distance = 2.22
#   * mlp.down_proj.max_weight = 0.81
#   * mlp.down_proj.max_weight_position = 34.09
#   * mlp.down_proj.min_weight = 0.50
#   * mlp.down_proj.min_weight_distance = 1.16
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0004
#   * Counting model refusals...
#   * Refusals: 98/100
#
# Elapsed time: 54m 15s
# Estimated remaining time: 46m 30s
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 177 of 200...
# * Parameters:
#   * direction_index = 28.65
#   * attn.o_proj.max_weight = 1.44
#   * attn.o_proj.max_weight_position = 25.25
#   * attn.o_proj.min_weight = 0.54
#   * attn.o_proj.min_weight_distance = 9.04
#   * mlp.down_proj.max_weight = 1.44
#   * mlp.down_proj.max_weight_position = 22.04
#   * mlp.down_proj.min_weight = 0.56
#   * mlp.down_proj.min_weight_distance = 3.83
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0068
#   * Counting model refusals...
#   * Refusals: 73/100
#
# Elapsed time: 56m 10s
# Estimated remaining time: 44m 33s
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 178 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 1.38
#   * attn.o_proj.max_weight_position = 32.76
#   * attn.o_proj.min_weight = 0.05
#   * attn.o_proj.min_weight_distance = 17.05
#   * mlp.down_proj.max_weight = 1.28
#   * mlp.down_proj.max_weight_position = 32.85
#   * mlp.down_proj.min_weight = 0.04
#   * mlp.down_proj.min_weight_distance = 16.86
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0171
#   * Counting model refusals...
#   * Refusals: 61/100
#
# Elapsed time: 58m 6s
# Estimated remaining time: 42m 36s
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 179 of 200...
# * Parameters:
#   * direction_index = 14.43
#   * attn.o_proj.max_weight = 0.99
#   * attn.o_proj.max_weight_position = 30.63
#   * attn.o_proj.min_weight = 0.12
#   * attn.o_proj.min_weight_distance = 19.36
#   * mlp.down_proj.max_weight = 1.38
#   * mlp.down_proj.max_weight_position = 23.14
#   * mlp.down_proj.min_weight = 1.01
#   * mlp.down_proj.min_weight_distance = 4.52
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0006
#   * Counting model refusals...
#   * Refusals: 98/100
#
# Elapsed time: 1h 0m
# Estimated remaining time: 40m 39s
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 180 of 200...
# * Parameters:
#   * direction_index = 29.49
#   * attn.o_proj.max_weight = 0.87
#   * attn.o_proj.max_weight_position = 34.07
#   * attn.o_proj.min_weight = 0.13
#   * attn.o_proj.min_weight_distance = 20.57
#   * mlp.down_proj.max_weight = 1.08
#   * mlp.down_proj.max_weight_position = 21.13
#   * mlp.down_proj.min_weight = 0.14
#   * mlp.down_proj.min_weight_distance = 2.49
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0022
#   * Counting model refusals...
#   * Refusals: 85/100
#
# Elapsed time: 1h 1m
# Estimated remaining time: 38m 43s
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 181 of 200...
# * Parameters:
#   * direction_index = 14.36
#   * attn.o_proj.max_weight = 0.84
#   * attn.o_proj.max_weight_position = 23.35
#   * attn.o_proj.min_weight = 0.15
#   * attn.o_proj.min_weight_distance = 14.36
#   * mlp.down_proj.max_weight = 0.85
#   * mlp.down_proj.max_weight_position = 34.00
#   * mlp.down_proj.min_weight = 0.56
#   * mlp.down_proj.min_weight_distance = 2.02
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0006
#   * Counting model refusals...
#   * Refusals: 96/100
#
# Elapsed time: 1h 3m
# Estimated remaining time: 36m 46s
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 182 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 1.19
#   * attn.o_proj.max_weight_position = 24.46
#   * attn.o_proj.min_weight = 0.12
#   * attn.o_proj.min_weight_distance = 6.12
#   * mlp.down_proj.max_weight = 1.40
#   * mlp.down_proj.max_weight_position = 29.60
#   * mlp.down_proj.min_weight = 1.37
#   * mlp.down_proj.min_weight_distance = 2.44
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0061
#   * Counting model refusals...
#   * Refusals: 78/100
#
# Elapsed time: 1h 5m
# Estimated remaining time: 34m 49s
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 183 of 200...
# * Parameters:
#   * direction_index = 22.48
#   * attn.o_proj.max_weight = 1.16
#   * attn.o_proj.max_weight_position = 26.20
#   * attn.o_proj.min_weight = 1.14
#   * attn.o_proj.min_weight_distance = 18.83
#   * mlp.down_proj.max_weight = 0.93
#   * mlp.down_proj.max_weight_position = 33.75
#   * mlp.down_proj.min_weight = 0.25
#   * mlp.down_proj.min_weight_distance = 20.09
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0019
#   * Counting model refusals...
#   * Refusals: 29/100
#
# Elapsed time: 1h 7m
# Estimated remaining time: 32m 54s
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 184 of 200...
# * Parameters:
#   * direction_index = 29.99
#   * attn.o_proj.max_weight = 1.49
#   * attn.o_proj.max_weight_position = 31.06
#   * attn.o_proj.min_weight = 1.29
#   * attn.o_proj.min_weight_distance = 4.58
#   * mlp.down_proj.max_weight = 1.41
#   * mlp.down_proj.max_weight_position = 32.95
#   * mlp.down_proj.min_weight = 1.20
#   * mlp.down_proj.min_weight_distance = 19.60
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0084
#   * Counting model refusals...
#   * Refusals: 83/100
#
# Elapsed time: 1h 9m
# Estimated remaining time: 30m 57s
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 185 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 0.86
#   * attn.o_proj.max_weight_position = 23.80
#   * attn.o_proj.min_weight = 0.08
#   * attn.o_proj.min_weight_distance = 3.20
#   * mlp.down_proj.max_weight = 0.95
#   * mlp.down_proj.max_weight_position = 31.82
#   * mlp.down_proj.min_weight = 0.01
#   * mlp.down_proj.min_weight_distance = 18.45
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0172
#   * Counting model refusals...
#   * Refusals: 78/100
#
# Elapsed time: 1h 11m
# Estimated remaining time: 29m 1s
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 186 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 0.98
#   * attn.o_proj.max_weight_position = 27.64
#   * attn.o_proj.min_weight = 0.24
#   * attn.o_proj.min_weight_distance = 17.09
#   * mlp.down_proj.max_weight = 1.50
#   * mlp.down_proj.max_weight_position = 21.38
#   * mlp.down_proj.min_weight = 1.45
#   * mlp.down_proj.min_weight_distance = 18.62
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0604
#   * Counting model refusals...
#   * Refusals: 10/100
#
# Elapsed time: 1h 13m
# Estimated remaining time: 27m 5s
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 187 of 200...
# * Parameters:
#   * direction_index = 15.73
#   * attn.o_proj.max_weight = 1.42
#   * attn.o_proj.max_weight_position = 34.36
#   * attn.o_proj.min_weight = 0.27
#   * attn.o_proj.min_weight_distance = 19.83
#   * mlp.down_proj.max_weight = 0.84
#   * mlp.down_proj.max_weight_position = 30.51
#   * mlp.down_proj.min_weight = 0.45
#   * mlp.down_proj.min_weight_distance = 15.47
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0005
#   * Counting model refusals...
#   * Refusals: 93/100
#
# Elapsed time: 1h 15m
# Estimated remaining time: 25m 9s
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 188 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 0.89
#   * attn.o_proj.max_weight_position = 26.92
#   * attn.o_proj.min_weight = 0.09
#   * attn.o_proj.min_weight_distance = 11.87
#   * mlp.down_proj.max_weight = 0.88
#   * mlp.down_proj.max_weight_position = 21.91
#   * mlp.down_proj.min_weight = 0.34
#   * mlp.down_proj.min_weight_distance = 7.26
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0264
#   * Counting model refusals...
#   * Refusals: 62/100
#
# Elapsed time: 1h 17m
# Estimated remaining time: 23m 13s
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 189 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 1.00
#   * attn.o_proj.max_weight_position = 34.90
#   * attn.o_proj.min_weight = 0.99
#   * attn.o_proj.min_weight_distance = 6.03
#   * mlp.down_proj.max_weight = 1.47
#   * mlp.down_proj.max_weight_position = 26.82
#   * mlp.down_proj.min_weight = 1.46
#   * mlp.down_proj.min_weight_distance = 18.19
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0435
#   * Counting model refusals...
#   * Refusals: 44/100
#
# Elapsed time: 1h 19m
# Estimated remaining time: 21m 17s
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 190 of 200...
# * Parameters:
#   * direction_index = 30.54
#   * attn.o_proj.max_weight = 0.83
#   * attn.o_proj.max_weight_position = 33.63
#   * attn.o_proj.min_weight = 0.81
#   * attn.o_proj.min_weight_distance = 3.81
#   * mlp.down_proj.max_weight = 0.95
#   * mlp.down_proj.max_weight_position = 23.87
#   * mlp.down_proj.min_weight = 0.11
#   * mlp.down_proj.min_weight_distance = 15.68
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0040
#   * Counting model refusals...
#   * Refusals: 87/100
#
# Elapsed time: 1h 21m
# Estimated remaining time: 19m 21s
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 191 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 1.28
#   * attn.o_proj.max_weight_position = 22.09
#   * attn.o_proj.min_weight = 1.27
#   * attn.o_proj.min_weight_distance = 2.06
#   * mlp.down_proj.max_weight = 0.89
#   * mlp.down_proj.max_weight_position = 31.41
#   * mlp.down_proj.min_weight = 0.36
#   * mlp.down_proj.min_weight_distance = 20.26
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0228
#   * Counting model refusals...
#   * Refusals: 57/100
#
# Elapsed time: 1h 23m
# Estimated remaining time: 17m 25s
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 192 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 0.95
#   * attn.o_proj.max_weight_position = 34.06
#   * attn.o_proj.min_weight = 0.10
#   * attn.o_proj.min_weight_distance = 1.31
#   * mlp.down_proj.max_weight = 1.37
#   * mlp.down_proj.max_weight_position = 25.72
#   * mlp.down_proj.min_weight = 1.04
#   * mlp.down_proj.min_weight_distance = 5.33
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0334
#   * Counting model refusals...
#   * Refusals: 85/100
#
# Elapsed time: 1h 25m
# Estimated remaining time: 15m 28s
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 193 of 200...
# * Parameters:
#   * direction_index = 25.95
#   * attn.o_proj.max_weight = 1.06
#   * attn.o_proj.max_weight_position = 33.73
#   * attn.o_proj.min_weight = 0.21
#   * attn.o_proj.min_weight_distance = 12.15
#   * mlp.down_proj.max_weight = 1.37
#   * mlp.down_proj.max_weight_position = 22.71
#   * mlp.down_proj.min_weight = 0.16
#   * mlp.down_proj.min_weight_distance = 18.14
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0042
#   * Counting model refusals...
#   * Refusals: 68/100
#
# Elapsed time: 1h 27m
# Estimated remaining time: 13m 32s
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 194 of 200...
# * Parameters:
#   * direction_index = 27.50
#   * attn.o_proj.max_weight = 1.42
#   * attn.o_proj.max_weight_position = 34.68
#   * attn.o_proj.min_weight = 0.54
#   * attn.o_proj.min_weight_distance = 15.93
#   * mlp.down_proj.max_weight = 1.45
#   * mlp.down_proj.max_weight_position = 34.12
#   * mlp.down_proj.min_weight = 1.24
#   * mlp.down_proj.min_weight_distance = 1.12
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0020
#   * Counting model refusals...
#   * Refusals: 86/100
#
# Elapsed time: 1h 28m
# Estimated remaining time: 11m 36s
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 195 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 0.94
#   * attn.o_proj.max_weight_position = 24.22
#   * attn.o_proj.min_weight = 0.10
#   * attn.o_proj.min_weight_distance = 2.34
#   * mlp.down_proj.max_weight = 1.47
#   * mlp.down_proj.max_weight_position = 21.65
#   * mlp.down_proj.min_weight = 0.13
#   * mlp.down_proj.min_weight_distance = 11.64
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0443
#   * Counting model refusals...
#   * Refusals: 52/100
#
# Elapsed time: 1h 30m
# Estimated remaining time: 9m 40s
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 196 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 0.91
#   * attn.o_proj.max_weight_position = 21.79
#   * attn.o_proj.min_weight = 0.47
#   * attn.o_proj.min_weight_distance = 6.09
#   * mlp.down_proj.max_weight = 1.38
#   * mlp.down_proj.max_weight_position = 22.87
#   * mlp.down_proj.min_weight = 0.65
#   * mlp.down_proj.min_weight_distance = 5.32
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0364
#   * Counting model refusals...
#   * Refusals: 39/100
#
# Elapsed time: 1h 32m
# Estimated remaining time: 7m 44s
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 197 of 200...
# * Parameters:
#   * direction_index = 21.45
#   * attn.o_proj.max_weight = 1.42
#   * attn.o_proj.max_weight_position = 33.57
#   * attn.o_proj.min_weight = 0.51
#   * attn.o_proj.min_weight_distance = 5.96
#   * mlp.down_proj.max_weight = 0.80
#   * mlp.down_proj.max_weight_position = 27.39
#   * mlp.down_proj.min_weight = 0.10
#   * mlp.down_proj.min_weight_distance = 2.17
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0001
#   * Counting model refusals...
#   * Refusals: 97/100
#
# Elapsed time: 1h 34m
# Estimated remaining time: 5m 48s
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 198 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 1.44
#   * attn.o_proj.max_weight_position = 21.27
#   * attn.o_proj.min_weight = 1.30
#   * attn.o_proj.min_weight_distance = 11.78
#   * mlp.down_proj.max_weight = 1.50
#   * mlp.down_proj.max_weight_position = 21.10
#   * mlp.down_proj.min_weight = 1.00
#   * mlp.down_proj.min_weight_distance = 12.72
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0445
#   * Counting model refusals...
#   * Refusals: 6/100
#
# Elapsed time: 1h 36m
# Estimated remaining time: 3m 52s
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Running trial 199 of 200...
# * Parameters:
#   * direction_index = 29.98
#   * attn.o_proj.max_weight = 1.15
#   * attn.o_proj.max_weight_position = 33.56
#   * attn.o_proj.min_weight = 0.35
#   * attn.o_proj.min_weight_distance = 9.86
#   * mlp.down_proj.max_weight = 0.93
#   * mlp.down_proj.max_weight_position = 32.60
#   * mlp.down_proj.min_weight = 0.90
#   * mlp.down_proj.min_weight_distance = 12.84
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0044
#   * Counting model refusals...
#   * Refusals: 90/100
#
# Elapsed time: 1h 38m
# Estimated remaining time: 1m 56s
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.14 GB
#
# Running trial 200 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 1.41
#   * attn.o_proj.max_weight_position = 31.98
#   * attn.o_proj.min_weight = 0.00
#   * attn.o_proj.min_weight_distance = 20.72
#   * mlp.down_proj.max_weight = 0.86
#   * mlp.down_proj.max_weight_position = 23.55
#   * mlp.down_proj.min_weight = 0.73
#   * mlp.down_proj.min_weight_distance = 13.37
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0293
#   * Counting model refusals...
#   * Refusals: 39/100
#
# Elapsed time: 1h 40m
# Resident system RAM: 1.92 GB
# Allocated GPU VRAM: 2.51 GB
# Reserved GPU VRAM: 13.15 GB
#
# Optimization finished!
#
# The following trials resulted in Pareto optimal combinations of refusals and KL
# divergence. After selecting a trial, you will be able to save the model, upload
# it to Hugging Face, chat with it to test how well it works, or run standard
# benchmarks on it. You can return to this menu later to select a different trial.
# Note that KL divergence values above 0.5 usually indicate significant damage to
# the original model's capabilities.
#
#
# Which trial do you want to use?
# [1] [Trial 162] Refusals:  4/100, KL divergence: 0.0027
# [2] [Trial 160] Refusals:  5/100, KL divergence: 0.0020
# [3] [Trial 157] Refusals:  7/100, KL divergence: 0.0018
# [4] [Trial 149] Refusals: 11/100, KL divergence: 0.0012
# [5] [Trial 132] Refusals: 65/100, KL divergence: 0.0008
# [6] [Trial  15] Refusals: 71/100, KL divergence: 0.0006
# [7] [Trial 187] Refusals: 93/100, KL divergence: 0.0005
# [8] [Trial 197] Refusals: 97/100, KL divergence: 0.0001
# [9] Run additional trials
# [10] Exit program
# Enter number: 1
#
# Restoring model from trial 162...
# * Parameters:
#   * direction_index = 18.19
#   * attn.o_proj.max_weight = 1.33
#   * attn.o_proj.max_weight_position = 31.31
#   * attn.o_proj.min_weight = 1.19
#   * attn.o_proj.min_weight_distance = 20.42
#   * mlp.down_proj.max_weight = 0.95
#   * mlp.down_proj.max_weight_position = 21.45
#   * mlp.down_proj.min_weight = 0.64
#   * mlp.down_proj.min_weight_distance = 17.61
# * Resetting model...
# * Abliterating...
#
#
# What do you want to do with the decensored model?
# [1] Save the model to a local folder
# [2] Upload the model to Hugging Face
# [3] Chat with the model
# [4] Benchmark the model
# [5] Return to the trial selection menu
# Enter number: 1
#
# Path to the folder:: /content/uncensored
#
# The model was loaded with quantization. Merging requires reloading the base
# model.
# WARNING: CPU merging requires dequantizing the entire model to system RAM.
# This can lead to system freezes if you run out of memory.
# Loading weights: 100% 398/398 [00:00<00:00, 821.17it/s]
# Estimated RAM required (excluding overhead): ~7.49 GB
#
#
# How do you want to export the model?
# [1] Merge the abliteration LoRA and export the full model (requires sufficient
# RAM)
# [2] Export the abliteration LoRA only (can be merged later)
# Enter number: 1
# Saving merged model...
# * Loading base model on CPU (this may take a while)...
# Loading weights: 100% 398/398 [00:00<00:00, 4704.60it/s]
# * Applying LoRA adapters...
# Error: Found an incompatible version of torchao. Found version 0.10.0, but only
# versions above 0.16.0 are supported
#
#
# What do you want to do with the decensored model?
# [1] Save the model to a local folder
# [2] Upload the model to Hugging Face
# [3] Chat with the model
# [4] Benchmark the model
# [5] Return to the trial selection menu
# Enter number:
# Shutting down...
# KeyboardInterrupt
# ^C
#
# ✅ Decensoring process complete! Move to the next cell to zip and download.

# %% [markdown]
# # 🚀 Read This Before going farther
#
# 🎯 Heretic Export Cheat Sheet
# * When trials finish, enter these inputs in sequence:
#
# * Select Best Trial: 1 (Lowest refusal score)
#
# * Export Action: 1 (Save to local folder)
#
# * Output Path: /content/output
#
# * Merge Method: 1 (Merge LoRA & export full model)
#
# * ⏳ Wait for Writing model shards: 100% to complete!
#
# * Back to Menu: 5
#
# * Exit Program: 14 / 10 (or the number for Exit)
#
#
# ---
# # 🎯 Remember!
#
#
# 💡 **Always download tokenizer_config.json from hugging face base model. Because Heretic will give you broken tokenizer_config.json!**
#
# 💡 **Download llama.cpp and Install it. After installing llama.cpp properly use this command below to generate GGUF file to run AI model in LMstudio or Ollama**
#
# 💡 **python convert_hf_to_gguf.py "/path/to/dir/[Folder Name Where All Files Saved]" --outfile /path/to/dir/[AI Model Name] --outtype auto**
#
# or,
#
# 💡 **./venv/bin/python convert_hf_to_gguf.py "/path/to/dir/[Folder Name Where All Files Saved]" --outfile /path/to/dir/[AI Model Name] --outtype auto**
#
# ---

# %% [markdown]
# ## **I DON'T RECOMMEND TO ZIP.**
# **YOU MAY NEED TO BE CAREFUL ABOUT FILE PATH. MANUALLY DOWNLOAD INSTEAD**

# %%
# @title 📦 2. Create Zip Archive
# @markdown Smart-scans Colab to find your new model folder and zips it up without missing a beat! 🎯

import os
import shutil

zip_output_path = "/content/uncensored_model"

# Smart search for the directory containing the new model files
model_dirs = []
for root, dirs, files in os.walk("/content"):
  if "config.json" in files and root != "/content":
    if ".cache" not in root and "huggingface" not in root:
      model_dirs.append(root)

if model_dirs:
  target_dir = model_dirs[0]
  print(f"🎯 Target model folder detected at: {target_dir}")
  print("⏳ Packing up model files into zip... (takes ~1 minute)")
  shutil.make_archive(zip_output_path, "zip", target_dir)
  print(f"🎉 Zip created successfully: {zip_output_path}.zip")
else:
  print("⚠️ No subfolder found, zipping main workspace directory...")
  shutil.make_archive(zip_output_path, "zip", "/content")
  print("🎉 Zip created successfully!")

# %% [markdown]
# # **Once Again!**
# **It will be best to manually download.**
#
# **But for large file, just copy path of that large file and paste in zip_file -> path. then click start. It will download large file if you face errors/abort message while manually downloading large file.📦⬇️**

# %%
# @title ⬇️ 3. Auto-Download Model
# @markdown Pushes your zip file straight into your browser download queue! 🚀

import os
from google.colab import files

zip_file = "/content/uncensored_model.zip"

if os.path.exists(zip_file):
  print("⬇️ Triggering browser download now...")
  files.download(zip_file)
else:
  print(
      "❌ Zip file missing! Make sure to hit play on Cell 3 (Create Zip"
      " Archive) first."
  )
