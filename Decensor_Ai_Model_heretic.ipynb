# %% [markdown]
# <a href="https://colab.research.google.com/github/boss-defender/Abliteration/blob/main/Decensor_Ai_Model_heretic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title 🚀 1. Decensor Model (All-in-One Smart Engine & Auto Resume) ⚡
# @markdown Enter any Hugging Face model! Checks GPU, auto-installs packages, mounts Drive, and resumes progress seamlessly.

MODEL_NAME = "Qwen/Qwen2.5-7B-Instruct"  # @param {type:"string"}
QUANTIZATION = "BNB_4BIT"  # @param ["BNB_4BIT", "NONE"] {allow-input: true}
HUGGINGFACE_TOKEN = ""  # @param {type:"string"}

import os
import shutil
import torch

# -------------------------------------------------------------------
# 🔍 1. GPU Diagnostics & VRAM Sanity Check
# -------------------------------------------------------------------
print("🩺 Running Pre-Flight System Diagnostics...")

if not torch.cuda.is_available():
  print(
      "\n❌ CRITICAL ERROR: No GPU detected!"
      "\n👉 Please go to top menu: Runtime -> Change runtime type -> Select T4 GPU"
      " (or A100)."
  )
  raise SystemExit("🚨 Process paused: GPU hardware is required to run Heretic.")
else:
  gpu_name = torch.cuda.get_device_name(0)
  vram_gb = torch.cuda.get_device_properties(0).total_memory / (1024**3)
  print(
      f"✅ GPU Online: {gpu_name} ({vram_gb:.2f} GB VRAM available) - Ready to"
      " melt weights! 🔥\n"
  )

# -------------------------------------------------------------------
# 📁 2. Mount Google Drive & Isolate Model Checkpoints
# -------------------------------------------------------------------
print("📁 Connecting Google Drive...")
from google.colab import drive

drive.mount("/content/drive")

# Generate a unique checkpoint folder based on the model name
clean_model_name = MODEL_NAME.replace("/", "_")
CHECKPOINT_DIR = (
    f"/content/drive/MyDrive/heretic_checkpoints/{clean_model_name}"
)
os.makedirs(CHECKPOINT_DIR, exist_ok=True)
print("✅ Drive connected! Checkpoint folder ready.\n")

# -------------------------------------------------------------------
# ⚙️ 3. Auto-Install Heretic Engine (if missing from session)
# -------------------------------------------------------------------
if not shutil.which("heretic"):
  print("🛠️ Heretic engine missing from current session! Installing now...")
  # !pip install -q -U heretic-llm bitsandbytes accelerate huggingface_hub
  print("🎉 Heretic & CUDA packages installed successfully!\n")
else:
  print("⚡ Heretic engine detected and active!\n")


# -------------------------------------------------------------------
# 🔑 4. Hugging Face Authentication
# -------------------------------------------------------------------
if HUGGINGFACE_TOKEN.strip():
  os.environ["HF_TOKEN"] = HUGGINGFACE_TOKEN.strip()
  # !huggingface-cli login --token $HUGGINGFACE_TOKEN.strip()

# -------------------------------------------------------------------
# 🔥 5. Launch Heretic Engine!
# -------------------------------------------------------------------
print(f"\n🚀 Igniting Heretic on model: {MODEL_NAME}")
print(f"💾 Isolated Checkpoint Folder: {CHECKPOINT_DIR}\n")

# !heretic --model "{MODEL_NAME}" --quantization {QUANTIZATION} --study-checkpoint-dir "{CHECKPOINT_DIR}"

print("\n✅ Decensoring process complete! Move to the next cell to zip and download.")
# Out:
# 🩺 Running Pre-Flight System Diagnostics...
# ✅ GPU Online: Tesla T4 (14.56 GB VRAM available) - Ready to melt weights! 🔥
#
# ⚡ Heretic engine detected and active!
#
# 📁 Connecting Google Drive...
# Mounted at /content/drive
#
# 🚀 Igniting Heretic on model: Qwen/Qwen2.5-3B-Instruct
# 💾 Isolated Checkpoint Folder: /content/drive/MyDrive/heretic_checkpoints/Qwen_Qwen2.5-3B-Instruct
#
# █░█░█▀▀░█▀▄░█▀▀░▀█▀░█░█▀▀  v1.4.0
# █▀█░█▀▀░█▀▄░█▀▀░░█░░█░█░░  https://heretic-project.org
# ▀░▀░▀▀▀░▀░▀░▀▀▀░░▀░░▀░▀▀▀  https://github.com/p-e-w/heretic
#
# Detected 1 CUDA device(s) (14.56 GB total VRAM)
# CUDA Version: 12.8
# Driver Version: 580.82.07
# * CUDA 0: Tesla T4 (14.56 GB)
#
# Loading model Qwen/Qwen2.5-3B-Instruct...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 100% 661/661 [00:00<00:00, 3.27MB/s]
# tokenizer_config.json: 100% 7.30k/7.30k [00:00<00:00, 12.0MB/s]
# vocab.json: 100% 2.78M/2.78M [00:00<00:00, 87.8MB/s]
# merges.txt: 100% 1.67M/1.67M [00:00<00:00, 122MB/s]
# tokenizer.json: 100% 7.03M/7.03M [00:00<00:00, 140MB/s]
# * Trying dtype auto...
# model.safetensors.index.json: 100% 35.6k/35.6k [00:00<00:00, 101MB/s]
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files:   0% 0/2 [00:00<?, ?it/s]
# Reconstructing (incomplete total...):   0% 0.00/6.17G [00:00<?, ?B/s]
# Downloading bytes:   0% 692k/6.17G [00:01<4:10:17, 411kB/s]
# Downloading bytes:  10% 591M/6.17G [00:03<00:17, 327MB/s,  312MB/s  ]
# Downloading bytes:  19% 1.19G/6.17G [00:05<00:13, 373MB/s,  360MB/s  ]
# Downloading bytes:  25% 1.56G/6.17G [00:06<00:24, 187MB/s,  201MB/s  ]
# Downloading bytes:  26% 1.63G/6.17G [00:07<00:37, 120MB/s,  110MB/s  ]
# Downloading bytes:  35% 2.17G/6.17G [00:10<00:23, 170MB/s,  211MB/s  ]
# Downloading bytes:  51% 3.15G/6.17G [00:14<00:16, 181MB/s,  205MB/s  ]
# Downloading bytes:  54% 3.34G/6.17G [00:15<00:16, 176MB/s,  188MB/s  ]
# Downloading bytes:  56% 3.43G/6.17G [00:16<00:16, 169MB/s,  161MB/s  ]
# Downloading bytes:  57% 3.49G/6.17G [00:16<00:11, 234MB/s,  208MB/s  ]
# Downloading bytes:  60% 3.72G/6.17G [00:17<00:11, 218MB/s,  267MB/s  ]
# Downloading bytes:  67% 4.15G/6.17G [00:19<00:07, 273MB/s,  271MB/s  ]
# Downloading bytes:  76% 4.71G/6.17G [00:21<00:08, 175MB/s,  185MB/s  ]
# Downloading bytes:  84% 5.21G/6.17G [00:24<00:05, 189MB/s,  204MB/s  ]
# Downloading bytes:  88% 5.41G/6.17G [00:26<00:04, 169MB/s,  204MB/s  ]
# Downloading bytes:  88% 5.41G/6.17G [00:44<00:04, 169MB/s,  169MB/s  ]
# Reconstructing (incomplete total...):  53% 3.28G/6.17G [00:51<01:05, 44.3MB/s, 49.0MB/s  ]
# Reconstructing (incomplete total...):  53% 3.28G/6.17G [01:04<01:05, 44.3MB/s, 44.3MB/s  ]
# Reconstructing (incomplete total...):  60% 3.71G/6.17G [01:05<01:04, 38.0MB/s, 44.3MB/s  ]
# Reconstructing (incomplete total...):  61% 3.74G/6.17G [01:06<01:03, 38.4MB/s, 38.0MB/s  ]
#
# Fetching 2 files:  50% 1/2 [01:07<01:07, 67.22s/it]
# Reconstructing (incomplete total...):  66% 4.06G/6.17G [01:12<00:49, 43.1MB/s, 38.4MB/s  ]
# Reconstructing (incomplete total...):  72% 4.45G/6.17G [01:17<00:33, 51.7MB/s, 43.1MB/s  ]
# Reconstructing (incomplete total...):  78% 4.82G/6.17G [01:22<00:24, 55.6MB/s, 51.7MB/s  ]
# Reconstructing (incomplete total...):  83% 5.09G/6.17G [01:32<00:24, 44.2MB/s, 55.6MB/s  ]
# Reconstructing (incomplete total...):  88% 5.46G/6.17G [01:34<00:11, 59.5MB/s, 44.2MB/s  ]
# Reconstructing (incomplete total...):  95% 5.85G/6.17G [01:36<00:04, 79.2MB/s, 59.5MB/s  ]
# Reconstructing (incomplete total...): 100% 6.17G/6.17G [01:40<00:00, 75.3MB/s, 79.2MB/s  ]
#
# Fetching 2 files: 100% 2/2 [01:40<00:00, 50.48s/it]
# Download complete: 100% 5.41G/5.41G [01:40<00:00, 169MB/s,  169MB/s  ]
# Download complete: 100% 5.41G/5.41G [01:41<00:00, 53.4MB/s,  169MB/s  ]
# Reconstruction complete: 100% 6.17G/6.17G [01:41<00:00, 60.9MB/s, 75.3MB/s  ]
# Loading weights: 100% 434/434 [00:19<00:00, 22.54it/s]
# generation_config.json: 100% 242/242 [00:00<00:00, 1.27MB/s]
# * Quantized to 4-bit precision
# * LoRA adapters initialized (target types: down_proj, o_proj)
# * Transformer model with 36 layers
# * Abliterable components:
#   * attn.o_proj: 36 modules total
#   * mlp.down_proj: 36 modules total
#
# Resident system RAM: 1.89 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 2.03 GB
#
# Loading good prompts from mlabonne/harmless_alpaca...
# README.md: 100% 388/388 [00:00<00:00, 793kB/s]
#
# data/train-00000-of-00001.parquet: downloading bytes:   9% 84.8k/972k [00:01<00:11, 75.6kB/s]
# data/train-00000-of-00001.parquet: downloading bytes: 100% 963k/963k [00:01<00:00, 849kB/s, 93.5kB/s  ]
# data/train-00000-of-00001.parquet: reconstructing file: 100% 972k/972k [00:01<00:00, 856kB/s, 94.3kB/s  ]
#
# data/test-00000-of-00001.parquet: downloading bytes:   0% 0.00/243k [00:00<?, ?B/s]
# data/test-00000-of-00001.parquet: downloading bytes: 100% 243k/243k [00:01<00:00, 219kB/s, 23.6kB/s  ]
# data/test-00000-of-00001.parquet: reconstructing file: 100% 243k/243k [00:01<00:00, 219kB/s, 23.6kB/s  ]
# Generating train split: 100% 25058/25058 [00:00<00:00, 167450.06 examples/s]
# Generating test split: 100% 6265/6265 [00:00<00:00, 270852.68 examples/s]
# * 400 prompts loaded
#
# Loading bad prompts from mlabonne/harmful_behaviors...
# README.md: 100% 381/381 [00:00<00:00, 1.18MB/s]
#
# data/train-00000-of-00001.parquet: downloading bytes:   0% 0.00/15.0k [00:00<?, ?B/s]
# data/train-00000-of-00001.parquet: downloading bytes: 100% 14.7k/14.7k [00:01<00:00, 13.8kB/s, 1.43kB/s  ]
# data/train-00000-of-00001.parquet: reconstructing file: 100% 15.0k/15.0k [00:01<00:00, 14.0kB/s, 1.46kB/s  ]
#
# data/test-00000-of-00001.parquet: downloading bytes:   0% 0.00/5.46k [00:00<?, ?B/s]
# data/test-00000-of-00001.parquet: downloading bytes: 100% 5.03k/5.03k [00:01<00:00, 4.59kB/s,   489B/s  ]
# data/test-00000-of-00001.parquet: reconstructing file: 100% 5.46k/5.46k [00:01<00:00, 4.99kB/s,   531B/s  ]
# Generating train split: 100% 416/416 [00:00<00:00, 185600.52 examples/s]
# Generating test split: 100% 104/104 [00:00<00:00, 57952.39 examples/s]
# * 400 prompts loaded
#
# Determining optimal batch size...
# * Trying batch size 1... Ok (12 tokens/s)
# * Trying batch size 2... Ok (19 tokens/s)
# * Trying batch size 4... Ok (35 tokens/s)
# * Trying batch size 8... Ok (29 tokens/s)
# * Trying batch size 16... Ok (53 tokens/s)
# * Trying batch size 32... Ok (93 tokens/s)
# * Trying batch size 64... Ok (149 tokens/s)
# * Trying batch size 128... Ok (163 tokens/s)
# * Chosen batch size: 128
#
# Checking for common response prefix...
# * None found
#
# Loading good evaluation prompts from mlabonne/harmless_alpaca...
# * 100 prompts loaded
# * Obtaining first-token probability distributions...
#
# Loading bad evaluation prompts from mlabonne/harmful_behaviors...
# * 100 prompts loaded
# * Counting model refusals...
# * Initial refusals: 96/100
#
# Calculating per-layer refusal directions...
# * Obtaining residual mean for good prompts...
# * Obtaining residual mean for bad prompts...
#
# Running trial 1 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 1.12
#   * attn.o_proj.max_weight_position = 21.26
#   * attn.o_proj.min_weight = 0.25
#   * attn.o_proj.min_weight_distance = 4.47
#   * mlp.down_proj.max_weight = 1.25
#   * mlp.down_proj.max_weight_position = 32.58
#   * mlp.down_proj.min_weight = 0.78
#   * mlp.down_proj.min_weight_distance = 3.56
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0467
#   * Counting model refusals...
#   * Refusals: 80/100
#
# Elapsed time: 1m 19s
# Estimated remaining time: 4h 20m
# Resident system RAM: 2.11 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 2 of 200...
# * Parameters:
#   * direction_index = 24.89
#   * attn.o_proj.max_weight = 0.83
#   * attn.o_proj.max_weight_position = 31.50
#   * attn.o_proj.min_weight = 0.61
#   * attn.o_proj.min_weight_distance = 14.09
#   * mlp.down_proj.max_weight = 1.46
#   * mlp.down_proj.max_weight_position = 34.83
#   * mlp.down_proj.min_weight = 0.32
#   * mlp.down_proj.min_weight_distance = 5.74
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0041
#   * Counting model refusals...
#   * Refusals: 94/100
#
# Elapsed time: 2m 37s
# Estimated remaining time: 4h 19m
# Resident system RAM: 2.11 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 3 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 0.84
#   * attn.o_proj.max_weight_position = 32.97
#   * attn.o_proj.min_weight = 0.49
#   * attn.o_proj.min_weight_distance = 1.70
#   * mlp.down_proj.max_weight = 1.40
#   * mlp.down_proj.max_weight_position = 21.43
#   * mlp.down_proj.min_weight = 0.47
#   * mlp.down_proj.min_weight_distance = 20.86
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.2309
#   * Counting model refusals...
#   * Refusals: 34/100
#
# Elapsed time: 3m 56s
# Estimated remaining time: 4h 18m
# Resident system RAM: 2.11 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 4 of 200...
# * Parameters:
#   * direction_index = 28.54
#   * attn.o_proj.max_weight = 0.80
#   * attn.o_proj.max_weight_position = 28.12
#   * attn.o_proj.min_weight = 0.26
#   * attn.o_proj.min_weight_distance = 14.98
#   * mlp.down_proj.max_weight = 1.09
#   * mlp.down_proj.max_weight_position = 21.05
#   * mlp.down_proj.min_weight = 0.94
#   * mlp.down_proj.min_weight_distance = 1.31
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0084
#   * Counting model refusals...
#   * Refusals: 93/100
#
# Elapsed time: 5m 15s
# Estimated remaining time: 4h 16m
# Resident system RAM: 2.11 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 5 of 200...
# * Parameters:
#   * direction_index = 19.78
#   * attn.o_proj.max_weight = 1.21
#   * attn.o_proj.max_weight_position = 26.75
#   * attn.o_proj.min_weight = 0.30
#   * attn.o_proj.min_weight_distance = 6.67
#   * mlp.down_proj.max_weight = 1.07
#   * mlp.down_proj.max_weight_position = 29.96
#   * mlp.down_proj.min_weight = 0.43
#   * mlp.down_proj.min_weight_distance = 14.91
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0158
#   * Counting model refusals...
#   * Refusals: 90/100
#
# Elapsed time: 6m 33s
# Estimated remaining time: 4h 15m
# Resident system RAM: 2.11 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 6 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 0.86
#   * attn.o_proj.max_weight_position = 22.42
#   * attn.o_proj.min_weight = 0.86
#   * attn.o_proj.min_weight_distance = 16.36
#   * mlp.down_proj.max_weight = 0.82
#   * mlp.down_proj.max_weight_position = 24.80
#   * mlp.down_proj.min_weight = 0.09
#   * mlp.down_proj.min_weight_distance = 6.13
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.1076
#   * Counting model refusals...
#   * Refusals: 53/100
#
# Elapsed time: 7m 52s
# Estimated remaining time: 4h 14m
# Resident system RAM: 2.11 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 7 of 200...
# * Parameters:
#   * direction_index = 21.38
#   * attn.o_proj.max_weight = 1.32
#   * attn.o_proj.max_weight_position = 30.39
#   * attn.o_proj.min_weight = 0.34
#   * attn.o_proj.min_weight_distance = 17.10
#   * mlp.down_proj.max_weight = 1.39
#   * mlp.down_proj.max_weight_position = 25.07
#   * mlp.down_proj.min_weight = 0.36
#   * mlp.down_proj.min_weight_distance = 8.07
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0495
#   * Counting model refusals...
#   * Refusals: 46/100
#
# Elapsed time: 9m 11s
# Estimated remaining time: 4h 13m
# Resident system RAM: 2.11 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 8 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 1.04
#   * attn.o_proj.max_weight_position = 29.68
#   * attn.o_proj.min_weight = 0.66
#   * attn.o_proj.min_weight_distance = 9.70
#   * mlp.down_proj.max_weight = 0.99
#   * mlp.down_proj.max_weight_position = 24.62
#   * mlp.down_proj.min_weight = 0.31
#   * mlp.down_proj.min_weight_distance = 6.00
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.1201
#   * Counting model refusals...
#   * Refusals: 52/100
#
# Elapsed time: 10m 30s
# Estimated remaining time: 4h 11m
# Resident system RAM: 2.11 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 9 of 200...
# * Parameters:
#   * direction_index = 25.70
#   * attn.o_proj.max_weight = 1.21
#   * attn.o_proj.max_weight_position = 31.69
#   * attn.o_proj.min_weight = 0.78
#   * attn.o_proj.min_weight_distance = 14.54
#   * mlp.down_proj.max_weight = 1.09
#   * mlp.down_proj.max_weight_position = 30.15
#   * mlp.down_proj.min_weight = 0.03
#   * mlp.down_proj.min_weight_distance = 8.46
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0183
#   * Counting model refusals...
#   * Refusals: 78/100
#
# Elapsed time: 11m 48s
# Estimated remaining time: 4h 10m
# Resident system RAM: 2.11 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 10 of 200...
# * Parameters:
#   * direction_index = 29.57
#   * attn.o_proj.max_weight = 1.24
#   * attn.o_proj.max_weight_position = 21.60
#   * attn.o_proj.min_weight = 0.76
#   * attn.o_proj.min_weight_distance = 16.06
#   * mlp.down_proj.max_weight = 1.35
#   * mlp.down_proj.max_weight_position = 30.14
#   * mlp.down_proj.min_weight = 0.66
#   * mlp.down_proj.min_weight_distance = 9.10
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0975
#   * Counting model refusals...
#   * Refusals: 44/100
#
# Elapsed time: 13m 7s
# Estimated remaining time: 4h 9m
# Resident system RAM: 2.11 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 11 of 200...
# * Parameters:
#   * direction_index = 16.57
#   * attn.o_proj.max_weight = 1.33
#   * attn.o_proj.max_weight_position = 28.08
#   * attn.o_proj.min_weight = 0.63
#   * attn.o_proj.min_weight_distance = 18.88
#   * mlp.down_proj.max_weight = 0.93
#   * mlp.down_proj.max_weight_position = 28.96
#   * mlp.down_proj.min_weight = 0.30
#   * mlp.down_proj.min_weight_distance = 8.55
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0112
#   * Counting model refusals...
#   * Refusals: 97/100
#
# Elapsed time: 14m 26s
# Estimated remaining time: 4h 7m
# Resident system RAM: 2.11 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 12 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 0.89
#   * attn.o_proj.max_weight_position = 26.77
#   * attn.o_proj.min_weight = 0.49
#   * attn.o_proj.min_weight_distance = 13.80
#   * mlp.down_proj.max_weight = 1.44
#   * mlp.down_proj.max_weight_position = 29.66
#   * mlp.down_proj.min_weight = 0.26
#   * mlp.down_proj.min_weight_distance = 12.50
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.1722
#   * Counting model refusals...
#   * Refusals: 36/100
#
# Elapsed time: 15m 45s
# Estimated remaining time: 4h 6m
# Resident system RAM: 2.11 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 13 of 200...
# * Parameters:
#   * direction_index = 26.32
#   * attn.o_proj.max_weight = 1.47
#   * attn.o_proj.max_weight_position = 31.64
#   * attn.o_proj.min_weight = 0.09
#   * attn.o_proj.min_weight_distance = 2.12
#   * mlp.down_proj.max_weight = 1.37
#   * mlp.down_proj.max_weight_position = 24.61
#   * mlp.down_proj.min_weight = 0.97
#   * mlp.down_proj.min_weight_distance = 6.12
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0814
#   * Counting model refusals...
#   * Refusals: 60/100
#
# Elapsed time: 17m 3s
# Estimated remaining time: 4h 5m
# Resident system RAM: 2.11 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 14 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 1.12
#   * attn.o_proj.max_weight_position = 32.02
#   * attn.o_proj.min_weight = 0.60
#   * attn.o_proj.min_weight_distance = 13.68
#   * mlp.down_proj.max_weight = 0.91
#   * mlp.down_proj.max_weight_position = 26.19
#   * mlp.down_proj.min_weight = 0.28
#   * mlp.down_proj.min_weight_distance = 13.32
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.1598
#   * Counting model refusals...
#   * Refusals: 47/100
#
# Elapsed time: 18m 22s
# Estimated remaining time: 4h 4m
# Resident system RAM: 2.11 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 15 of 200...
# * Parameters:
#   * direction_index = 23.77
#   * attn.o_proj.max_weight = 0.92
#   * attn.o_proj.max_weight_position = 24.54
#   * attn.o_proj.min_weight = 0.26
#   * attn.o_proj.min_weight_distance = 19.80
#   * mlp.down_proj.max_weight = 0.90
#   * mlp.down_proj.max_weight_position = 23.78
#   * mlp.down_proj.min_weight = 0.08
#   * mlp.down_proj.min_weight_distance = 2.38
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0098
#   * Counting model refusals...
#   * Refusals: 67/100
#
# Elapsed time: 19m 41s
# Estimated remaining time: 4h 2m
# Resident system RAM: 2.11 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 16 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 1.11
#   * attn.o_proj.max_weight_position = 24.36
#   * attn.o_proj.min_weight = 0.63
#   * attn.o_proj.min_weight_distance = 12.19
#   * mlp.down_proj.max_weight = 1.13
#   * mlp.down_proj.max_weight_position = 30.44
#   * mlp.down_proj.min_weight = 0.84
#   * mlp.down_proj.min_weight_distance = 8.86
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.1566
#   * Counting model refusals...
#   * Refusals: 39/100
#
# Elapsed time: 21m 0s
# Estimated remaining time: 4h 1m
# Resident system RAM: 2.11 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 17 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 1.45
#   * attn.o_proj.max_weight_position = 33.06
#   * attn.o_proj.min_weight = 0.83
#   * attn.o_proj.min_weight_distance = 17.77
#   * mlp.down_proj.max_weight = 1.42
#   * mlp.down_proj.max_weight_position = 22.68
#   * mlp.down_proj.min_weight = 1.26
#   * mlp.down_proj.min_weight_distance = 19.55
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.3875
#   * Counting model refusals...
#   * Refusals: 7/100
#
# Elapsed time: 22m 19s
# Estimated remaining time: 4h 0m
# Resident system RAM: 2.11 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 18 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 1.29
#   * attn.o_proj.max_weight_position = 29.92
#   * attn.o_proj.min_weight = 0.52
#   * attn.o_proj.min_weight_distance = 20.04
#   * mlp.down_proj.max_weight = 0.96
#   * mlp.down_proj.max_weight_position = 28.65
#   * mlp.down_proj.min_weight = 0.44
#   * mlp.down_proj.min_weight_distance = 3.34
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0845
#   * Counting model refusals...
#   * Refusals: 55/100
#
# Elapsed time: 23m 38s
# Estimated remaining time: 3h 58m
# Resident system RAM: 2.11 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 19 of 200...
# * Parameters:
#   * direction_index = 24.60
#   * attn.o_proj.max_weight = 1.38
#   * attn.o_proj.max_weight_position = 27.55
#   * attn.o_proj.min_weight = 0.74
#   * attn.o_proj.min_weight_distance = 7.10
#   * mlp.down_proj.max_weight = 1.27
#   * mlp.down_proj.max_weight_position = 33.16
#   * mlp.down_proj.min_weight = 0.75
#   * mlp.down_proj.min_weight_distance = 3.27
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0053
#   * Counting model refusals...
#   * Refusals: 90/100
#
# Elapsed time: 24m 56s
# Estimated remaining time: 3h 57m
# Resident system RAM: 2.11 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 20 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 1.08
#   * attn.o_proj.max_weight_position = 29.19
#   * attn.o_proj.min_weight = 1.03
#   * attn.o_proj.min_weight_distance = 4.19
#   * mlp.down_proj.max_weight = 1.43
#   * mlp.down_proj.max_weight_position = 31.78
#   * mlp.down_proj.min_weight = 0.50
#   * mlp.down_proj.min_weight_distance = 10.44
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.1061
#   * Counting model refusals...
#   * Refusals: 65/100
#
# Elapsed time: 26m 15s
# Estimated remaining time: 3h 56m
# Resident system RAM: 2.11 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 21 of 200...
# * Parameters:
#   * direction_index = 31.48
#   * attn.o_proj.max_weight = 1.01
#   * attn.o_proj.max_weight_position = 31.59
#   * attn.o_proj.min_weight = 0.26
#   * attn.o_proj.min_weight_distance = 9.97
#   * mlp.down_proj.max_weight = 1.32
#   * mlp.down_proj.max_weight_position = 30.72
#   * mlp.down_proj.min_weight = 0.42
#   * mlp.down_proj.min_weight_distance = 5.45
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0966
#   * Counting model refusals...
#   * Refusals: 83/100
#
# Elapsed time: 27m 33s
# Estimated remaining time: 3h 54m
# Resident system RAM: 2.11 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 22 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 0.91
#   * attn.o_proj.max_weight_position = 32.84
#   * attn.o_proj.min_weight = 0.27
#   * attn.o_proj.min_weight_distance = 6.60
#   * mlp.down_proj.max_weight = 1.10
#   * mlp.down_proj.max_weight_position = 29.63
#   * mlp.down_proj.min_weight = 0.65
#   * mlp.down_proj.min_weight_distance = 7.63
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0896
#   * Counting model refusals...
#   * Refusals: 73/100
#
# Elapsed time: 28m 52s
# Estimated remaining time: 3h 53m
# Resident system RAM: 2.11 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 23 of 200...
# * Parameters:
#   * direction_index = 28.88
#   * attn.o_proj.max_weight = 1.02
#   * attn.o_proj.max_weight_position = 30.05
#   * attn.o_proj.min_weight = 0.41
#   * attn.o_proj.min_weight_distance = 4.74
#   * mlp.down_proj.max_weight = 1.02
#   * mlp.down_proj.max_weight_position = 27.94
#   * mlp.down_proj.min_weight = 0.11
#   * mlp.down_proj.min_weight_distance = 15.71
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0653
#   * Counting model refusals...
#   * Refusals: 66/100
#
# Elapsed time: 30m 11s
# Estimated remaining time: 3h 52m
# Resident system RAM: 2.11 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 24 of 200...
# * Parameters:
#   * direction_index = 18.52
#   * attn.o_proj.max_weight = 1.33
#   * attn.o_proj.max_weight_position = 30.38
#   * attn.o_proj.min_weight = 0.89
#   * attn.o_proj.min_weight_distance = 16.84
#   * mlp.down_proj.max_weight = 1.36
#   * mlp.down_proj.max_weight_position = 21.11
#   * mlp.down_proj.min_weight = 0.03
#   * mlp.down_proj.min_weight_distance = 18.55
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0707
#   * Counting model refusals...
#   * Refusals: 81/100
#
# Elapsed time: 31m 30s
# Estimated remaining time: 3h 50m
# Resident system RAM: 2.11 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 25 of 200...
# * Parameters:
#   * direction_index = 22.03
#   * attn.o_proj.max_weight = 1.18
#   * attn.o_proj.max_weight_position = 21.34
#   * attn.o_proj.min_weight = 0.61
#   * attn.o_proj.min_weight_distance = 15.33
#   * mlp.down_proj.max_weight = 1.26
#   * mlp.down_proj.max_weight_position = 23.45
#   * mlp.down_proj.min_weight = 0.21
#   * mlp.down_proj.min_weight_distance = 10.05
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0690
#   * Counting model refusals...
#   * Refusals: 10/100
#
# Elapsed time: 32m 49s
# Estimated remaining time: 3h 49m
# Resident system RAM: 2.11 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 26 of 200...
# * Parameters:
#   * direction_index = 30.62
#   * attn.o_proj.max_weight = 1.31
#   * attn.o_proj.max_weight_position = 22.92
#   * attn.o_proj.min_weight = 0.20
#   * attn.o_proj.min_weight_distance = 19.85
#   * mlp.down_proj.max_weight = 0.97
#   * mlp.down_proj.max_weight_position = 33.10
#   * mlp.down_proj.min_weight = 0.23
#   * mlp.down_proj.min_weight_distance = 18.40
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0784
#   * Counting model refusals...
#   * Refusals: 64/100
#
# Elapsed time: 34m 7s
# Estimated remaining time: 3h 48m
# Resident system RAM: 2.11 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 27 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 1.36
#   * attn.o_proj.max_weight_position = 26.15
#   * attn.o_proj.min_weight = 0.33
#   * attn.o_proj.min_weight_distance = 4.37
#   * mlp.down_proj.max_weight = 1.34
#   * mlp.down_proj.max_weight_position = 25.93
#   * mlp.down_proj.min_weight = 0.33
#   * mlp.down_proj.min_weight_distance = 18.88
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.2137
#   * Counting model refusals...
#   * Refusals: 29/100
#
# Elapsed time: 35m 26s
# Estimated remaining time: 3h 47m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 28 of 200...
# * Parameters:
#   * direction_index = 23.32
#   * attn.o_proj.max_weight = 1.12
#   * attn.o_proj.max_weight_position = 23.88
#   * attn.o_proj.min_weight = 0.77
#   * attn.o_proj.min_weight_distance = 8.63
#   * mlp.down_proj.max_weight = 1.23
#   * mlp.down_proj.max_weight_position = 25.48
#   * mlp.down_proj.min_weight = 0.79
#   * mlp.down_proj.min_weight_distance = 13.46
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0746
#   * Counting model refusals...
#   * Refusals: 6/100
#
# Elapsed time: 36m 45s
# Estimated remaining time: 3h 45m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 29 of 200...
# * Parameters:
#   * direction_index = 15.55
#   * attn.o_proj.max_weight = 1.38
#   * attn.o_proj.max_weight_position = 33.62
#   * attn.o_proj.min_weight = 0.65
#   * attn.o_proj.min_weight_distance = 4.86
#   * mlp.down_proj.max_weight = 1.45
#   * mlp.down_proj.max_weight_position = 24.35
#   * mlp.down_proj.min_weight = 0.21
#   * mlp.down_proj.min_weight_distance = 13.21
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0137
#   * Counting model refusals...
#   * Refusals: 97/100
#
# Elapsed time: 38m 4s
# Estimated remaining time: 3h 44m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 30 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 1.13
#   * attn.o_proj.max_weight_position = 29.61
#   * attn.o_proj.min_weight = 1.09
#   * attn.o_proj.min_weight_distance = 4.30
#   * mlp.down_proj.max_weight = 1.35
#   * mlp.down_proj.max_weight_position = 29.45
#   * mlp.down_proj.min_weight = 0.02
#   * mlp.down_proj.min_weight_distance = 17.48
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.1535
#   * Counting model refusals...
#   * Refusals: 46/100
#
# Elapsed time: 39m 23s
# Estimated remaining time: 3h 43m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 31 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 1.22
#   * attn.o_proj.max_weight_position = 22.38
#   * attn.o_proj.min_weight = 0.76
#   * attn.o_proj.min_weight_distance = 19.79
#   * mlp.down_proj.max_weight = 1.07
#   * mlp.down_proj.max_weight_position = 22.83
#   * mlp.down_proj.min_weight = 0.87
#   * mlp.down_proj.min_weight_distance = 13.59
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.3089
#   * Counting model refusals...
#   * Refusals: 11/100
#
# Elapsed time: 40m 42s
# Estimated remaining time: 3h 41m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 32 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 1.22
#   * attn.o_proj.max_weight_position = 33.99
#   * attn.o_proj.min_weight = 0.34
#   * attn.o_proj.min_weight_distance = 18.47
#   * mlp.down_proj.max_weight = 1.16
#   * mlp.down_proj.max_weight_position = 34.55
#   * mlp.down_proj.min_weight = 0.44
#   * mlp.down_proj.min_weight_distance = 2.52
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0160
#   * Counting model refusals...
#   * Refusals: 83/100
#
# Elapsed time: 42m 0s
# Estimated remaining time: 3h 40m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 33 of 200...
# * Parameters:
#   * direction_index = 17.86
#   * attn.o_proj.max_weight = 0.94
#   * attn.o_proj.max_weight_position = 22.43
#   * attn.o_proj.min_weight = 0.93
#   * attn.o_proj.min_weight_distance = 2.99
#   * mlp.down_proj.max_weight = 0.82
#   * mlp.down_proj.max_weight_position = 29.54
#   * mlp.down_proj.min_weight = 0.58
#   * mlp.down_proj.min_weight_distance = 14.46
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0086
#   * Counting model refusals...
#   * Refusals: 95/100
#
# Elapsed time: 43m 19s
# Estimated remaining time: 3h 39m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 34 of 200...
# * Parameters:
#   * direction_index = 29.19
#   * attn.o_proj.max_weight = 1.10
#   * attn.o_proj.max_weight_position = 21.20
#   * attn.o_proj.min_weight = 0.05
#   * attn.o_proj.min_weight_distance = 3.47
#   * mlp.down_proj.max_weight = 0.92
#   * mlp.down_proj.max_weight_position = 34.81
#   * mlp.down_proj.min_weight = 0.42
#   * mlp.down_proj.min_weight_distance = 4.72
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0018
#   * Counting model refusals...
#   * Refusals: 97/100
#
# Elapsed time: 44m 37s
# Estimated remaining time: 3h 37m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 35 of 200...
# * Parameters:
#   * direction_index = 27.86
#   * attn.o_proj.max_weight = 1.45
#   * attn.o_proj.max_weight_position = 26.32
#   * attn.o_proj.min_weight = 0.04
#   * attn.o_proj.min_weight_distance = 4.14
#   * mlp.down_proj.max_weight = 1.21
#   * mlp.down_proj.max_weight_position = 33.59
#   * mlp.down_proj.min_weight = 0.84
#   * mlp.down_proj.min_weight_distance = 11.87
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0582
#   * Counting model refusals...
#   * Refusals: 61/100
#
# Elapsed time: 45m 56s
# Estimated remaining time: 3h 36m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 36 of 200...
# * Parameters:
#   * direction_index = 21.73
#   * attn.o_proj.max_weight = 1.26
#   * attn.o_proj.max_weight_position = 27.24
#   * attn.o_proj.min_weight = 0.40
#   * attn.o_proj.min_weight_distance = 2.38
#   * mlp.down_proj.max_weight = 1.06
#   * mlp.down_proj.max_weight_position = 28.79
#   * mlp.down_proj.min_weight = 0.13
#   * mlp.down_proj.min_weight_distance = 13.07
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0238
#   * Counting model refusals...
#   * Refusals: 89/100
#
# Elapsed time: 47m 14s
# Estimated remaining time: 3h 35m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 37 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 1.30
#   * attn.o_proj.max_weight_position = 27.17
#   * attn.o_proj.min_weight = 0.14
#   * attn.o_proj.min_weight_distance = 1.07
#   * mlp.down_proj.max_weight = 1.27
#   * mlp.down_proj.max_weight_position = 30.48
#   * mlp.down_proj.min_weight = 0.50
#   * mlp.down_proj.min_weight_distance = 12.33
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.1313
#   * Counting model refusals...
#   * Refusals: 60/100
#
# Elapsed time: 48m 33s
# Estimated remaining time: 3h 33m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 38 of 200...
# * Parameters:
#   * direction_index = 16.72
#   * attn.o_proj.max_weight = 1.13
#   * attn.o_proj.max_weight_position = 28.35
#   * attn.o_proj.min_weight = 0.12
#   * attn.o_proj.min_weight_distance = 16.65
#   * mlp.down_proj.max_weight = 1.24
#   * mlp.down_proj.max_weight_position = 34.02
#   * mlp.down_proj.min_weight = 0.58
#   * mlp.down_proj.min_weight_distance = 16.31
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0066
#   * Counting model refusals...
#   * Refusals: 97/100
#
# Elapsed time: 49m 52s
# Estimated remaining time: 3h 32m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 39 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 1.20
#   * attn.o_proj.max_weight_position = 27.73
#   * attn.o_proj.min_weight = 0.39
#   * attn.o_proj.min_weight_distance = 15.77
#   * mlp.down_proj.max_weight = 0.88
#   * mlp.down_proj.max_weight_position = 21.69
#   * mlp.down_proj.min_weight = 0.63
#   * mlp.down_proj.min_weight_distance = 6.21
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.1513
#   * Counting model refusals...
#   * Refusals: 33/100
#
# Elapsed time: 51m 10s
# Estimated remaining time: 3h 31m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 40 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 1.34
#   * attn.o_proj.max_weight_position = 27.77
#   * attn.o_proj.min_weight = 1.25
#   * attn.o_proj.min_weight_distance = 8.28
#   * mlp.down_proj.max_weight = 1.43
#   * mlp.down_proj.max_weight_position = 26.76
#   * mlp.down_proj.min_weight = 0.07
#   * mlp.down_proj.min_weight_distance = 20.83
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.2686
#   * Counting model refusals...
#   * Refusals: 13/100
#
# Elapsed time: 52m 29s
# Estimated remaining time: 3h 29m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 41 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 1.07
#   * attn.o_proj.max_weight_position = 32.65
#   * attn.o_proj.min_weight = 0.83
#   * attn.o_proj.min_weight_distance = 9.88
#   * mlp.down_proj.max_weight = 1.18
#   * mlp.down_proj.max_weight_position = 21.74
#   * mlp.down_proj.min_weight = 0.62
#   * mlp.down_proj.min_weight_distance = 11.21
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.1962
#   * Counting model refusals...
#   * Refusals: 36/100
#
# Elapsed time: 53m 48s
# Estimated remaining time: 3h 28m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 42 of 200...
# * Parameters:
#   * direction_index = 29.36
#   * attn.o_proj.max_weight = 0.91
#   * attn.o_proj.max_weight_position = 21.03
#   * attn.o_proj.min_weight = 0.36
#   * attn.o_proj.min_weight_distance = 19.15
#   * mlp.down_proj.max_weight = 1.35
#   * mlp.down_proj.max_weight_position = 27.08
#   * mlp.down_proj.min_weight = 0.29
#   * mlp.down_proj.min_weight_distance = 18.17
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.1218
#   * Counting model refusals...
#   * Refusals: 37/100
#
# Elapsed time: 55m 7s
# Estimated remaining time: 3h 27m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 43 of 200...
# * Parameters:
#   * direction_index = 14.50
#   * attn.o_proj.max_weight = 0.88
#   * attn.o_proj.max_weight_position = 30.15
#   * attn.o_proj.min_weight = 0.22
#   * attn.o_proj.min_weight_distance = 19.06
#   * mlp.down_proj.max_weight = 1.39
#   * mlp.down_proj.max_weight_position = 26.15
#   * mlp.down_proj.min_weight = 0.73
#   * mlp.down_proj.min_weight_distance = 14.65
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0129
#   * Counting model refusals...
#   * Refusals: 97/100
#
# Elapsed time: 56m 26s
# Estimated remaining time: 3h 26m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 44 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 1.36
#   * attn.o_proj.max_weight_position = 30.35
#   * attn.o_proj.min_weight = 0.69
#   * attn.o_proj.min_weight_distance = 9.88
#   * mlp.down_proj.max_weight = 1.36
#   * mlp.down_proj.max_weight_position = 24.69
#   * mlp.down_proj.min_weight = 0.70
#   * mlp.down_proj.min_weight_distance = 10.83
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.2491
#   * Counting model refusals...
#   * Refusals: 20/100
#
# Elapsed time: 57m 45s
# Estimated remaining time: 3h 24m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 45 of 200...
# * Parameters:
#   * direction_index = 26.32
#   * attn.o_proj.max_weight = 1.35
#   * attn.o_proj.max_weight_position = 28.74
#   * attn.o_proj.min_weight = 0.44
#   * attn.o_proj.min_weight_distance = 17.35
#   * mlp.down_proj.max_weight = 1.25
#   * mlp.down_proj.max_weight_position = 22.90
#   * mlp.down_proj.min_weight = 0.37
#   * mlp.down_proj.min_weight_distance = 8.68
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0795
#   * Counting model refusals...
#   * Refusals: 26/100
#
# Elapsed time: 59m 4s
# Estimated remaining time: 3h 23m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 46 of 200...
# * Parameters:
#   * direction_index = 28.28
#   * attn.o_proj.max_weight = 1.02
#   * attn.o_proj.max_weight_position = 28.12
#   * attn.o_proj.min_weight = 0.87
#   * attn.o_proj.min_weight_distance = 9.00
#   * mlp.down_proj.max_weight = 1.01
#   * mlp.down_proj.max_weight_position = 30.47
#   * mlp.down_proj.min_weight = 0.54
#   * mlp.down_proj.min_weight_distance = 20.84
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0728
#   * Counting model refusals...
#   * Refusals: 49/100
#
# Elapsed time: 1h 0m
# Estimated remaining time: 3h 22m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 47 of 200...
# * Parameters:
#   * direction_index = 15.46
#   * attn.o_proj.max_weight = 1.07
#   * attn.o_proj.max_weight_position = 25.37
#   * attn.o_proj.min_weight = 0.92
#   * attn.o_proj.min_weight_distance = 20.35
#   * mlp.down_proj.max_weight = 1.36
#   * mlp.down_proj.max_weight_position = 31.53
#   * mlp.down_proj.min_weight = 0.26
#   * mlp.down_proj.min_weight_distance = 18.98
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0371
#   * Counting model refusals...
#   * Refusals: 97/100
#
# Elapsed time: 1h 1m
# Estimated remaining time: 3h 20m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 48 of 200...
# * Parameters:
#   * direction_index = 19.71
#   * attn.o_proj.max_weight = 1.13
#   * attn.o_proj.max_weight_position = 32.55
#   * attn.o_proj.min_weight = 0.39
#   * attn.o_proj.min_weight_distance = 7.45
#   * mlp.down_proj.max_weight = 0.99
#   * mlp.down_proj.max_weight_position = 23.44
#   * mlp.down_proj.min_weight = 0.10
#   * mlp.down_proj.min_weight_distance = 14.87
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0252
#   * Counting model refusals...
#   * Refusals: 87/100
#
# Elapsed time: 1h 3m
# Estimated remaining time: 3h 19m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 49 of 200...
# * Parameters:
#   * direction_index = 30.60
#   * attn.o_proj.max_weight = 1.34
#   * attn.o_proj.max_weight_position = 21.56
#   * attn.o_proj.min_weight = 1.32
#   * attn.o_proj.min_weight_distance = 6.05
#   * mlp.down_proj.max_weight = 1.32
#   * mlp.down_proj.max_weight_position = 21.24
#   * mlp.down_proj.min_weight = 0.90
#   * mlp.down_proj.min_weight_distance = 12.72
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.1281
#   * Counting model refusals...
#   * Refusals: 46/100
#
# Elapsed time: 1h 4m
# Estimated remaining time: 3h 18m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 50 of 200...
# * Parameters:
#   * direction_index = 21.48
#   * attn.o_proj.max_weight = 0.80
#   * attn.o_proj.max_weight_position = 27.52
#   * attn.o_proj.min_weight = 0.53
#   * attn.o_proj.min_weight_distance = 9.93
#   * mlp.down_proj.max_weight = 1.23
#   * mlp.down_proj.max_weight_position = 25.78
#   * mlp.down_proj.min_weight = 0.24
#   * mlp.down_proj.min_weight_distance = 13.58
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0446
#   * Counting model refusals...
#   * Refusals: 42/100
#
# Elapsed time: 1h 5m
# Estimated remaining time: 3h 16m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 51 of 200...
# * Parameters:
#   * direction_index = 20.79
#   * attn.o_proj.max_weight = 0.94
#   * attn.o_proj.max_weight_position = 31.93
#   * attn.o_proj.min_weight = 0.73
#   * attn.o_proj.min_weight_distance = 9.36
#   * mlp.down_proj.max_weight = 1.50
#   * mlp.down_proj.max_weight_position = 21.24
#   * mlp.down_proj.min_weight = 0.21
#   * mlp.down_proj.min_weight_distance = 11.53
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0981
#   * Counting model refusals...
#   * Refusals: 30/100
#
# Elapsed time: 1h 6m
# Estimated remaining time: 3h 15m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 52 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 0.93
#   * attn.o_proj.max_weight_position = 34.90
#   * attn.o_proj.min_weight = 0.32
#   * attn.o_proj.min_weight_distance = 20.75
#   * mlp.down_proj.max_weight = 1.43
#   * mlp.down_proj.max_weight_position = 27.52
#   * mlp.down_proj.min_weight = 0.45
#   * mlp.down_proj.min_weight_distance = 19.28
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.2440
#   * Counting model refusals...
#   * Refusals: 22/100
#
# Elapsed time: 1h 8m
# Estimated remaining time: 3h 14m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 53 of 200...
# * Parameters:
#   * direction_index = 20.35
#   * attn.o_proj.max_weight = 1.37
#   * attn.o_proj.max_weight_position = 32.72
#   * attn.o_proj.min_weight = 1.01
#   * attn.o_proj.min_weight_distance = 6.10
#   * mlp.down_proj.max_weight = 1.24
#   * mlp.down_proj.max_weight_position = 21.23
#   * mlp.down_proj.min_weight = 0.20
#   * mlp.down_proj.min_weight_distance = 2.79
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0092
#   * Counting model refusals...
#   * Refusals: 92/100
#
# Elapsed time: 1h 9m
# Estimated remaining time: 3h 12m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 54 of 200...
# * Parameters:
#   * direction_index = 14.54
#   * attn.o_proj.max_weight = 1.34
#   * attn.o_proj.max_weight_position = 33.16
#   * attn.o_proj.min_weight = 0.08
#   * attn.o_proj.min_weight_distance = 13.09
#   * mlp.down_proj.max_weight = 1.11
#   * mlp.down_proj.max_weight_position = 21.46
#   * mlp.down_proj.min_weight = 0.15
#   * mlp.down_proj.min_weight_distance = 11.63
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0053
#   * Counting model refusals...
#   * Refusals: 96/100
#
# Elapsed time: 1h 10m
# Estimated remaining time: 3h 11m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 55 of 200...
# * Parameters:
#   * direction_index = 30.21
#   * attn.o_proj.max_weight = 1.02
#   * attn.o_proj.max_weight_position = 28.40
#   * attn.o_proj.min_weight = 0.26
#   * attn.o_proj.min_weight_distance = 7.72
#   * mlp.down_proj.max_weight = 1.40
#   * mlp.down_proj.max_weight_position = 24.47
#   * mlp.down_proj.min_weight = 0.88
#   * mlp.down_proj.min_weight_distance = 10.43
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.1338
#   * Counting model refusals...
#   * Refusals: 61/100
#
# Elapsed time: 1h 12m
# Estimated remaining time: 3h 10m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 56 of 200...
# * Parameters:
#   * direction_index = 14.28
#   * attn.o_proj.max_weight = 1.08
#   * attn.o_proj.max_weight_position = 21.10
#   * attn.o_proj.min_weight = 0.37
#   * attn.o_proj.min_weight_distance = 16.04
#   * mlp.down_proj.max_weight = 0.93
#   * mlp.down_proj.max_weight_position = 33.35
#   * mlp.down_proj.min_weight = 0.45
#   * mlp.down_proj.min_weight_distance = 7.46
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0091
#   * Counting model refusals...
#   * Refusals: 96/100
#
# Elapsed time: 1h 13m
# Estimated remaining time: 3h 9m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 57 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 1.40
#   * attn.o_proj.max_weight_position = 25.10
#   * attn.o_proj.min_weight = 1.36
#   * attn.o_proj.min_weight_distance = 3.04
#   * mlp.down_proj.max_weight = 1.24
#   * mlp.down_proj.max_weight_position = 28.78
#   * mlp.down_proj.min_weight = 0.86
#   * mlp.down_proj.min_weight_distance = 8.48
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.1543
#   * Counting model refusals...
#   * Refusals: 43/100
#
# Elapsed time: 1h 14m
# Estimated remaining time: 3h 7m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 58 of 200...
# * Parameters:
#   * direction_index = 27.32
#   * attn.o_proj.max_weight = 0.87
#   * attn.o_proj.max_weight_position = 28.71
# ...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0492
#   * Counting model refusals...
#   * Refusals: 26/100
#
# Elapsed time: 1h 47m
# Estimated remaining time: 2h 35m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 83 of 200...
# * Parameters:
#   * direction_index = 19.29
#   * attn.o_proj.max_weight = 0.92
#   * attn.o_proj.max_weight_position = 25.61
#   * attn.o_proj.min_weight = 0.47
#   * attn.o_proj.min_weight_distance = 19.87
#   * mlp.down_proj.max_weight = 0.87
#   * mlp.down_proj.max_weight_position = 28.34
#   * mlp.down_proj.min_weight = 0.32
#   * mlp.down_proj.min_weight_distance = 3.04
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0062
#   * Counting model refusals...
#   * Refusals: 91/100
#
# Elapsed time: 1h 49m
# Estimated remaining time: 2h 33m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 84 of 200...
# * Parameters:
#   * direction_index = 24.91
#   * attn.o_proj.max_weight = 1.08
#   * attn.o_proj.max_weight_position = 22.27
#   * attn.o_proj.min_weight = 0.30
#   * attn.o_proj.min_weight_distance = 17.15
#   * mlp.down_proj.max_weight = 0.89
#   * mlp.down_proj.max_weight_position = 27.45
#   * mlp.down_proj.min_weight = 0.05
#   * mlp.down_proj.min_weight_distance = 18.32
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0322
#   * Counting model refusals...
#   * Refusals: 41/100
#
# Elapsed time: 1h 50m
# Estimated remaining time: 2h 32m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 85 of 200...
# * Parameters:
#   * direction_index = 25.48
#   * attn.o_proj.max_weight = 0.98
#   * attn.o_proj.max_weight_position = 24.05
#   * attn.o_proj.min_weight = 0.31
#   * attn.o_proj.min_weight_distance = 16.03
#   * mlp.down_proj.max_weight = 0.94
#   * mlp.down_proj.max_weight_position = 27.12
#   * mlp.down_proj.min_weight = 0.04
#   * mlp.down_proj.min_weight_distance = 13.53
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0349
#   * Counting model refusals...
#   * Refusals: 53/100
#
# Elapsed time: 1h 51m
# Estimated remaining time: 2h 31m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 86 of 200...
# * Parameters:
#   * direction_index = 27.34
#   * attn.o_proj.max_weight = 1.20
#   * attn.o_proj.max_weight_position = 23.07
#   * attn.o_proj.min_weight = 0.37
#   * attn.o_proj.min_weight_distance = 19.39
#   * mlp.down_proj.max_weight = 0.84
#   * mlp.down_proj.max_weight_position = 27.11
#   * mlp.down_proj.min_weight = 0.05
#   * mlp.down_proj.min_weight_distance = 17.64
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0513
#   * Counting model refusals...
#   * Refusals: 51/100
#
# Elapsed time: 1h 52m
# Estimated remaining time: 2h 29m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 87 of 200...
# * Parameters:
#   * direction_index = 25.66
#   * attn.o_proj.max_weight = 0.83
#   * attn.o_proj.max_weight_position = 21.97
#   * attn.o_proj.min_weight = 0.10
#   * attn.o_proj.min_weight_distance = 15.83
#   * mlp.down_proj.max_weight = 0.96
#   * mlp.down_proj.max_weight_position = 28.22
#   * mlp.down_proj.min_weight = 0.12
#   * mlp.down_proj.min_weight_distance = 15.91
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0356
#   * Counting model refusals...
#   * Refusals: 58/100
#
# Elapsed time: 1h 54m
# Estimated remaining time: 2h 28m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 88 of 200...
# * Parameters:
#   * direction_index = 26.55
#   * attn.o_proj.max_weight = 1.02
#   * attn.o_proj.max_weight_position = 22.73
#   * attn.o_proj.min_weight = 0.59
#   * attn.o_proj.min_weight_distance = 19.84
#   * mlp.down_proj.max_weight = 0.82
#   * mlp.down_proj.max_weight_position = 23.66
#   * mlp.down_proj.min_weight = 0.18
#   * mlp.down_proj.min_weight_distance = 2.49
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0139
#   * Counting model refusals...
#   * Refusals: 75/100
#
# Elapsed time: 1h 55m
# Estimated remaining time: 2h 27m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 89 of 200...
# * Parameters:
#   * direction_index = 22.28
#   * attn.o_proj.max_weight = 0.91
#   * attn.o_proj.max_weight_position = 21.29
#   * attn.o_proj.min_weight = 0.40
#   * attn.o_proj.min_weight_distance = 16.60
#   * mlp.down_proj.max_weight = 0.94
#   * mlp.down_proj.max_weight_position = 21.62
#   * mlp.down_proj.min_weight = 0.16
#   * mlp.down_proj.min_weight_distance = 1.98
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0476
#   * Counting model refusals...
#   * Refusals: 76/100
#
# Elapsed time: 1h 56m
# Estimated remaining time: 2h 25m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 90 of 200...
# * Parameters:
#   * direction_index = 25.54
#   * attn.o_proj.max_weight = 0.94
#   * attn.o_proj.max_weight_position = 26.63
#   * attn.o_proj.min_weight = 0.59
#   * attn.o_proj.min_weight_distance = 20.92
#   * mlp.down_proj.max_weight = 0.84
#   * mlp.down_proj.max_weight_position = 22.07
#   * mlp.down_proj.min_weight = 0.09
#   * mlp.down_proj.min_weight_distance = 1.06
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0066
#   * Counting model refusals...
#   * Refusals: 82/100
#
# Elapsed time: 1h 58m
# Estimated remaining time: 2h 24m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 91 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 1.03
#   * attn.o_proj.max_weight_position = 22.23
#   * attn.o_proj.min_weight = 0.25
#   * attn.o_proj.min_weight_distance = 16.41
#   * mlp.down_proj.max_weight = 0.98
#   * mlp.down_proj.max_weight_position = 27.20
#   * mlp.down_proj.min_weight = 0.33
#   * mlp.down_proj.min_weight_distance = 18.37
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.2073
#   * Counting model refusals...
#   * Refusals: 27/100
#
# Elapsed time: 1h 59m
# Estimated remaining time: 2h 23m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 92 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 1.02
#   * attn.o_proj.max_weight_position = 26.46
#   * attn.o_proj.min_weight = 0.37
#   * attn.o_proj.min_weight_distance = 19.83
#   * mlp.down_proj.max_weight = 0.80
#   * mlp.down_proj.max_weight_position = 25.17
#   * mlp.down_proj.min_weight = 0.18
#   * mlp.down_proj.min_weight_distance = 4.85
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0899
#   * Counting model refusals...
#   * Refusals: 55/100
#
# Elapsed time: 2h 0m
# Estimated remaining time: 2h 21m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 93 of 200...
# * Parameters:
#   * direction_index = 28.98
#   * attn.o_proj.max_weight = 1.11
#   * attn.o_proj.max_weight_position = 25.92
#   * attn.o_proj.min_weight = 0.19
#   * attn.o_proj.min_weight_distance = 19.74
#   * mlp.down_proj.max_weight = 0.96
#   * mlp.down_proj.max_weight_position = 25.79
#   * mlp.down_proj.min_weight = 0.65
#   * mlp.down_proj.min_weight_distance = 19.21
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0837
#   * Counting model refusals...
#   * Refusals: 39/100
#
# Elapsed time: 2h 2m
# Estimated remaining time: 2h 20m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 94 of 200...
# * Parameters:
#   * direction_index = 23.81
#   * attn.o_proj.max_weight = 1.00
#   * attn.o_proj.max_weight_position = 24.70
#   * attn.o_proj.min_weight = 0.49
#   * attn.o_proj.min_weight_distance = 18.89
#   * mlp.down_proj.max_weight = 0.90
#   * mlp.down_proj.max_weight_position = 26.92
#   * mlp.down_proj.min_weight = 0.02
#   * mlp.down_proj.min_weight_distance = 5.28
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0111
#   * Counting model refusals...
#   * Refusals: 70/100
#
# Elapsed time: 2h 3m
# Estimated remaining time: 2h 19m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 95 of 200...
# * Parameters:
#   * direction_index = 26.41
#   * attn.o_proj.max_weight = 0.94
#   * attn.o_proj.max_weight_position = 25.03
#   * attn.o_proj.min_weight = 0.62
#   * attn.o_proj.min_weight_distance = 17.11
#   * mlp.down_proj.max_weight = 0.91
#   * mlp.down_proj.max_weight_position = 24.99
#   * mlp.down_proj.min_weight = 0.69
#   * mlp.down_proj.min_weight_distance = 19.28
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0599
#   * Counting model refusals...
#   * Refusals: 28/100
#
# Elapsed time: 2h 4m
# Estimated remaining time: 2h 17m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 96 of 200...
# * Parameters:
#   * direction_index = per layer
#   * attn.o_proj.max_weight = 0.92
#   * attn.o_proj.max_weight_position = 21.46
#   * attn.o_proj.min_weight = 0.07
#   * attn.o_proj.min_weight_distance = 19.25
#   * mlp.down_proj.max_weight = 0.91
#   * mlp.down_proj.max_weight_position = 21.63
#   * mlp.down_proj.min_weight = 0.42
#   * mlp.down_proj.min_weight_distance = 20.81
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.2140
#   * Counting model refusals...
#   * Refusals: 32/100
#
# Elapsed time: 2h 6m
# Estimated remaining time: 2h 16m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 97 of 200...
# * Parameters:
#   * direction_index = 19.42
#   * attn.o_proj.max_weight = 1.06
#   * attn.o_proj.max_weight_position = 21.55
#   * attn.o_proj.min_weight = 0.58
#   * attn.o_proj.min_weight_distance = 14.79
#   * mlp.down_proj.max_weight = 0.85
#   * mlp.down_proj.max_weight_position = 25.40
#   * mlp.down_proj.min_weight = 0.31
#   * mlp.down_proj.min_weight_distance = 17.46
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0311
#   * Counting model refusals...
#   * Refusals: 79/100
#
# Elapsed time: 2h 7m
# Estimated remaining time: 2h 15m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 98 of 200...
# * Parameters:
#   * direction_index = 24.31
#   * attn.o_proj.max_weight = 0.91
#   * attn.o_proj.max_weight_position = 22.71
#   * attn.o_proj.min_weight = 0.41
#   * attn.o_proj.min_weight_distance = 18.09
#   * mlp.down_proj.max_weight = 0.86
#   * mlp.down_proj.max_weight_position = 24.17
#   * mlp.down_proj.min_weight = 0.45
#   * mlp.down_proj.min_weight_distance = 20.85
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0372
#   * Counting model refusals...
#   * Refusals: 17/100
#
# Elapsed time: 2h 8m
# Estimated remaining time: 2h 14m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 99 of 200...
# * Parameters:
#   * direction_index = 20.89
#   * attn.o_proj.max_weight = 0.95
#   * attn.o_proj.max_weight_position = 21.04
#   * attn.o_proj.min_weight = 0.09
#   * attn.o_proj.min_weight_distance = 19.18
#   * mlp.down_proj.max_weight = 0.86
#   * mlp.down_proj.max_weight_position = 25.51
#   * mlp.down_proj.min_weight = 0.03
#   * mlp.down_proj.min_weight_distance = 5.80
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0252
#   * Counting model refusals...
#   * Refusals: 86/100
#
# Elapsed time: 2h 10m
# Estimated remaining time: 2h 12m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 100 of 200...
# * Parameters:
#   * direction_index = 20.83
#   * attn.o_proj.max_weight = 1.12
#   * attn.o_proj.max_weight_position = 22.17
#   * attn.o_proj.min_weight = 0.32
#   * attn.o_proj.min_weight_distance = 20.40
#   * mlp.down_proj.max_weight = 1.08
#   * mlp.down_proj.max_weight_position = 26.52
#   * mlp.down_proj.min_weight = 0.05
#   * mlp.down_proj.min_weight_distance = 16.42
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0539
#   * Counting model refusals...
#   * Refusals: 43/100
#
# Elapsed time: 2h 11m
# Estimated remaining time: 2h 11m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 101 of 200...
# * Parameters:
#   * direction_index = 23.29
#   * attn.o_proj.max_weight = 0.95
#   * attn.o_proj.max_weight_position = 22.85
#   * attn.o_proj.min_weight = 0.38
#   * attn.o_proj.min_weight_distance = 18.79
#   * mlp.down_proj.max_weight = 0.86
#   * mlp.down_proj.max_weight_position = 32.93
#   * mlp.down_proj.min_weight = 0.08
#   * mlp.down_proj.min_weight_distance = 19.46
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0205
#   * Counting model refusals...
#   * Refusals: 71/100
#
# Elapsed time: 2h 12m
# Estimated remaining time: 2h 10m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 102 of 200...
# * Parameters:
#   * direction_index = 26.47
#   * attn.o_proj.max_weight = 0.85
#   * attn.o_proj.max_weight_position = 27.40
#   * attn.o_proj.min_weight = 0.36
#   * attn.o_proj.min_weight_distance = 13.25
#   * mlp.down_proj.max_weight = 0.91
#   * mlp.down_proj.max_weight_position = 21.85
#   * mlp.down_proj.min_weight = 0.16
#   * mlp.down_proj.min_weight_distance = 10.27
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0359
#   * Counting model refusals...
#   * Refusals: 63/100
#
# Elapsed time: 2h 14m
# Estimated remaining time: 2h 8m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 103 of 200...
# * Parameters:
#   * direction_index = 24.97
#   * attn.o_proj.max_weight = 1.09
#   * attn.o_proj.max_weight_position = 21.18
#   * attn.o_proj.min_weight = 0.11
#   * attn.o_proj.min_weight_distance = 13.28
#   * mlp.down_proj.max_weight = 0.88
#   * mlp.down_proj.max_weight_position = 26.57
#   * mlp.down_proj.min_weight = 0.26
#   * mlp.down_proj.min_weight_distance = 20.60
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0337
#   * Counting model refusals...
#   * Refusals: 38/100
#
# Elapsed time: 2h 15m
# Estimated remaining time: 2h 7m
# Resident system RAM: 2.12 GB
# Allocated GPU VRAM: 1.94 GB
# Reserved GPU VRAM: 4.62 GB
#
# Running trial 104 of 200...
# * Parameters:
#   * direction_index = 27.94
#   * attn.o_proj.max_weight = 0.97
#   * attn.o_proj.max_weight_position = 21.48
#   * attn.o_proj.min_weight = 0.27
#   * attn.o_proj.min_weight_distance = 18.95
#   * mlp.down_proj.max_weight = 0.98
#   * mlp.down_proj.max_weight_position = 23.78
#   * mlp.down_proj.min_weight = 0.49
#   * mlp.down_proj.min_weight_distance = 19.74
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.0654
#   * Counting model refusals...
# ^C
#
# ✅ Decensoring process complete! Move to the next cell to zip and download.

# %%
# @title 📦 2. Create Zip Archive
# @markdown Smart-scans Colab to find your new model folder and zips it up without missing a beat! 🎯

import os
import shutil

zip_output_path = "/content/uncensored_model"

# Smart search for the directory containing the new model files
model_dirs = []
for root, dirs, files in os.walk("/content"):
  if "config.json" in files and root != "/content":
    if ".cache" not in root and "huggingface" not in root:
      model_dirs.append(root)

if model_dirs:
  target_dir = model_dirs[0]
  print(f"🎯 Target model folder detected at: {target_dir}")
  print("⏳ Packing up model files into zip... (takes ~1 minute)")
  shutil.make_archive(zip_output_path, "zip", target_dir)
  print(f"🎉 Zip created successfully: {zip_output_path}.zip")
else:
  print("⚠️ No subfolder found, zipping main workspace directory...")
  shutil.make_archive(zip_output_path, "zip", "/content")
  print("🎉 Zip created successfully!")

# %%
# @title ⬇️ 3. Auto-Download Model
# @markdown Pushes your zip file straight into your browser download queue! 🚀

import os
from google.colab import files

zip_file = "/content/uncensored_model.zip"

if os.path.exists(zip_file):
  print("⬇️ Triggering browser download now...")
  files.download(zip_file)
else:
  print(
      "❌ Zip file missing! Make sure to hit play on Cell 3 (Create Zip"
      " Archive) first."
  )
